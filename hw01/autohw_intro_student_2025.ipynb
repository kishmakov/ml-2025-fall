# %% [markdown]
# ## Лабораторная работа 1. Введение в ML

# %% [markdown]
# В этой лабораторной вы:
#
# - познакомитесь с базовыми библиотеками для работы с табличными данными — `numpy` и `pandas`
# - поближе посмотрите на простейшие задачи машинного обучения: классификацию и регрессию
# - попробуете несколько метрик и поймёте, почему выбор метрики это важно
# - обучите несколько простых моделей
# - увидите связь между сложностью модели и переобучением
# - убедитесь, что без данных всё тлен

# %% [markdown]
# Загрузка самых базовых библиотек:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split

# %% [markdown]
# ### [NumPy](https://numpy.org/doc/stable/user/index.html)
#
# С 1995 numeric, с 2006 NumPy — «Numerical Python extensions» или просто «NumPy»
#
# Возможности библиотеки NumPy:
# * работать с многомерными массивами (таблицами)
# * быстро вычислять математические функций на многомерных массивах
#
# Ядро пакета NumPy — объект [ndarray](https://docs.scipy.org/doc/numpy/reference/generated/numpy.ndarray.html)
#
# **Важные отличия** между NumPy arrays и Python sequences:
# * NumPy array имеет фиксированную длину, которая определяется в момент его создания (в отличие от Python lists, которые могут расти динамически)
# * Элементы в NumPy array должны быть одного типа
# * Можно выполнять операции непосредственно над NumPy arrays
#
# **Скорость** NumPy достигается с помощью:
# * реализации на C
# * векторизации и броадкастинга (broadcasting). Например, произведение массивов совместимых форм.
#
# Теперь давайте разберёмся подробнее и сделаем что-нибудь приятное и полезное в `numpy`!

# %% [markdown]
# ### Индексация

# %% [markdown]
# В NumPy работает привычная индексация Python, ура! Включая использование отрицательных индексов и срезов (slices)

# %% [markdown]
# <div class="alert alert-info">
# <b>Замечание 1:</b> Индексы и срезы в многомерных массивах не нужно разделять квадратными скобками,
# т.е. вместо <b>matrix[i][j]</b> нужно использовать <b>matrix[i, j]</b>. Первое тоже работает, но сначала выдаёт строку i, потом элемент j в ней.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Замечание 2:</b> Срезы в NumPy создают view, а не копии, как в случае срезов встроенных последовательностей Python (string, tuple and list).
# </div>

# %%
ones_matrix = np.ones((5, 5))
ones_submatrix_view = ones_matrix[::2,::2] # creates a view, not copy
ones_matrix[::2,::2] = np.ones((3, 3))
ones_submatrix_view
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %% [markdown]
# ### Ссылка на Яндекс.Контест
#
# Решения и ответы в задачах, расположенных ниже, загружайте в контест на автоматическую проверку:
# https://contest.yandex.ru/contest/39295/enter

# %% [markdown]
# **1. (1 балл)** Реализуйте функцию, принимающую на вход два одномерных массива `first_array` и `second_array` и возвращающую матрицу, в которой первый массив соответствует первому столбцу матрицы, второй — второму.
#
# Вероятно первое, что приходит вам на ум, это конкатенация и транспонирование:

# %%
def construct_matrix(x, y):
    return np.column_stack((x, y))

# %%
construct_matrix(np.array([1,2]),np.array([3,4]))
# Out:
# array([[1, 3],
#        [2, 4]])

# %% [markdown]
# (в скобках заметим, что конкатенировать можно vertically, horizontally, depth wise методами vstack, hstack, dstack по трём осям (0, 1 и 2, соотвественно), либо в общем случае `np.concatenate` — поиграйтесь ниже с прекрасным примером четырёхмерной точки, чтобы точно всё для себя понять)

# %%
p = np.arange(1).reshape([1, 1, 1, 1])
p
# Out:
# array([[[[0]]]])

# %%
print("vstack: ", np.vstack((p, p)).shape)
print("hstack: ", np.hstack((p, p)).shape)
print("dstack: ", np.dstack((p, p)).shape)
# Out:
# vstack:  (2, 1, 1, 1)
# hstack:  (1, 2, 1, 1)
# dstack:  (1, 1, 2, 1)

# %%
np.concatenate((p, p), axis=3).shape
# Out:
# (1, 1, 1, 2)

# %% [markdown]
# Но, поскольку операция транспонирования [делает массив non-contiguous](https://numpy.org/doc/stable/user/basics.copies.html#other-operations), мы в этой задаче **запретим** ей пользоваться и порекомедуем воспользоваться, например, методом [reshape](https://numpy.org/doc/stable/reference/generated/numpy.reshape.html).

# %% [markdown]
# **2. (1 балл)** Реализуйте функцию, принимающую на вход массив целых неотрицательных чисел `nums` и возвращающую самый частый элемент массива.

# %%
def most_frequent(nums):
    """
    Find the most frequent value in an array
    :param nums: array of ints
    :return: the most frequent value
    """
    # Handle empty input robustly for both Python lists and numpy arrays
    if nums is None:
        return None
    if np.size(nums) == 0:
        return None

    # Count frequency of each element
    counts = {}
    for num in nums:
        counts[num] = counts.get(num, 0) + 1

    # Find the element with maximum frequency
    max_count = 0
    most_frequent_num = nums[0]

    for num, count in counts.items():
        if count > max_count:
            max_count = count
            most_frequent_num = num

    return most_frequent_num

# %% [markdown]
# ### Переходим к работе с данными
#
# Прежде всего, загрузим данные и сделаем из них красивые pandas-таблички. Они взяты из параллели RecSys соревнования https://yandex.ru/cup/ml/. Но мы будем иметь дело не со всеми данными, а только с их частью. Данные у нас будут про заведения общественного питания (больше бюрократический терминологии!)
#
# Задачей будет **предсказание среднего чека** (average_bill) по некоторым другим свойствам заведения.

# %%
base = './'

# %%
data = pd.read_csv(base + 'organisations.csv')
features = pd.read_csv(base + 'features.csv')
rubrics = pd.read_csv(base + 'rubrics.csv')

# %% [markdown]
# В основном мы будем работать с табличкой `data`; остальное вам может пригодиться, если вы захотите знать, какое содержание стоит за кодами признаков.

# %% [markdown]
# ## Изучение данных

# %% [markdown]
# Посмотрите на данные. В этом вам поможет метод ``head`` pandas-таблички.

# %%
data.head()
# Out:
#                  org_id city  average_bill    rating   rubrics_id  \
# 0  15903868628669802651  msk        1500.0  4.270968  30776 30774
# 1  16076540698036998306  msk         500.0  4.375000        30771
# 2   8129364761615040323  msk         500.0  4.000000        31495
# 3  15262729117594253452  msk         500.0  4.538813  30776 30770
# 4  13418544315327784420  msk         500.0  4.409091        31495
#
#                                          features_id
# 0  3501685156 3501779478 20422 3502045016 3502045...
# 1  1509 1082283206 273469383 10462 11617 35017794...
# 2  10462 11177 11617 11629 1416 1018 11704 11867 ...
# 3  3501618484 2020795524 11629 11617 1018 11704 2...
# 4  11617 10462 11177 1416 11867 3501744275 20282 ...

# %% [markdown]
# Полезно посмотреть внимательнее на то, с какими признаками нам предстоит работать.
#
# * **org_id** вам не понадобится;
# * **city** - город, в котором находится заведение (``msk`` или ``spb``);
# * **average_bill** - средний чек в заведении - он будет нашим таргетом;
# * **rating** - рейтинг заведения;
# * **rubrics_id** - тип заведения (или несколько типов). Соответствие кодов каким-то человекочитаемым типам живёт в табличке ``rubrics``
# * **features_id** - набор неких фичей заведения. Соответствие кодов каким-то человекочитаемым типам живёт в табличке ``features``
#
# Обратите внимание, что **rubrics_id** и **features_id** - это не списки, а разделённые пробелами строки. Когда вам захочется работать с отдельными фичами из мешка фичей для данного заведения, вам придётся всё-таки превратить их в списки (здесь поможет метод `split` для строк).

# %% [markdown]
# Чтобы быстро восстанавливать по рубрикам и фичам их нормальные названия, сделайте словари вида ``код_фичи:название_фичи``

# %%
feature_dict = features.set_index('feature_id')['feature_name'].to_dict()
feature_dict
# Out:
# {1: 'prepress_and_post_printing_processing',
#  40: 'products',
#  54: 'printing_method',
#  77: 'fuel',
#  79: 'shop',
#  82: 'last_minute_deals_only',
#  104: 'tour_type',
#  110: 'audio_guide',
#  111: 'cargo_transportation',
#  113: 'manufacturing',
#  114: 'installation',
#  115: 'repairs',
#  116: 'production',
#  117: 'sale',
#  133: 'music_genre',
#  135: 'electroniccigarette',
#  137: 'variety_food',
#  140: 'room_disabled',
#  175: 'arts',
#  246: 'karaoke',
#  249: 'street_theatre',
#  253: 'performance',
#  256: 'vip_zone',
#  270: 'money_transfers',
#  275: 'loans_private_individuals',
#  282: 'sober_driver',
#  288: 'accepted_credit_cards',
#  305: 'refrigerator',
#  308: 'minibar',
#  312: 'room_number',
#  328: 'speciality',
#  337: 'type_of_rooms',
#  344: 'building_repair',
#  349: 'hospital_profile',
#  354: 'type_parking',
#  372: 'services_corporate_clients',
#  379: 'currency_exchange',
#  392: 'debit_cards',
#  402: 'improving_driver_qualifications',
#  405: 'female_instructor',
#  409: 'medical_board',
#  425: 'training_machines',
#  427: 'target_audience',
#  433: 'business_lending',
#  444: 'has_restaurant',
#  447: 'air_conditioning',
#  536: 'country',
#  540: 'online_sales',
#  542: 'stadium_type',
#  545: 'car_valeting',
#  594: 'pro_shop',
#  598: 'body_repair',
#  601: 'car_park',
#  602: 'hair_removal',
#  636: 'imax',
#  726: 'cosmetology_services',
#  790: 'pets',
#  795: 'hotel_type',
#  803: 'massage_services',
#  873: 'leasing_registration',
#  883: '3d',
#  956: 'railway_tickets',
#  962: 'services_specialists',
#  980: 'trade_in',
#  983: 'star',
#  989: 'form_of_training',
#  995: 'staging_of_dancing_routines',
#  1018: 'food_delivery',
#  1054: 'car_wash',
#  1059: 'additional_services',
#  1070: 'official_dealer',
#  1075: 'pool',
#  1091: 'atm',
#  1104: 'loan_processing',
#  1113: 'registration_inspection',
#  1124: 'car_brand',
#  1131: 'online_recording',
#  1246: 'type_of_museum',
#  1257: 'test_drive',
#  1261: 'flights',
#  1271: 'cash_desk',
#  1413: 'sauna',
#  1415: 'nursery',
#  1416: 'type_cuisine',
#  1509: 'special_menu',
#  1524: 'type_public_catering',
#  1572: 'type_waterpark',
#  1573: 'childrens_town',
#  1575: 'water_purification_method',
#  1582: 'water_activities',
#  1587: 'wave_pool',
#  1589: 'pool_type',
#  1592: 'number_of_swimming_lanes',
#  1600: 'group_classes',
#  1627: 'gym',
#  1629: 'sport_game',
#  1651: 'martial_arts',
#  1702: 'covering',
#  1703: 'dance',
#  1753: 'hairdressing_services',
#  1783: 'types_of_tanning_beds',
#  1796: 'figure_correction',
#  1819: 'nail_procedures',
#  1840: 'for_children',
#  1877: 'vehicle_fleet',
#  1879: 'training_category',
#  1888: 'holding_of_bowling_tournaments',
#  1889: 'conducting_pool_tournaments',
#  1891: 'storage_of_client_pool_equipment',
#  1892: 'storage_of_client_bowling_equipment',
#  1893: 'billiard_school',
#  1894: 'bowling_for_children',
#  1897: 'bowling_school',
#  1900: 'wedding_dances',
#  1903: 'artists_for_events',
#  1935: 'services_veterinary_clinic',
#  1937: 'state',
#  10427: 'price_delivery',
#  10428: 'hall_capacity',
#  10429: 'price_hour',
#  10430: 'time_order',
#  10434: 'tickets',
#  10437: 'washing_zones',
#  10440: 'russian_billiard',
#  10441: 'track_length',
#  10442: 'year_of_foundation',
#  10447: 'kalyan',
#  10448: 'price_evening',
#  10449: 'price_per_hour_sauna2',
#  10450: 'price_taxi',
#  10451: 'price_per_month3',
#  10459: 'women_haircut',
#  10462: 'average_bill2',
#  10463: 'price_8',
#  10470: 'hall',
#  10480: 'cartridge',
#  10481: 'water_stuff',
#  10487: 'price_1',
#  10502: 'pool_backflow',
#  10506: 'sports_medicine',
#  10512: 'outfit',
#  10513: 'baggage_room',
#  10514: 'skate_rental',
#  10515: 'skate_sharpening',
#  10518: 'kids_club',
#  10556: 'weekend_group',
#  10557: 'language',
#  10560: 'door_type',
#  10563: 'spa',
#  10564: 'type_food',
#  10565: 'visa_support',
#  10580: 'bridal_assortment',
#  10588: 'laundry',
#  10596: 'minimum_order',
#  10597: 'natural_reservoir',
#  10600: 'admission_by_appointment',
#  10656: 'wheel_alignment',
#  10668: 'car_rental',
#  10669: 'animal_transportation',
#  10676: 'kindergarden_features',
#  10718: 'clothes_and_shoe_repairs',
#  10722: 'beauty_salon',
#  10744: 'dry_cleaners_',
#  10746: 'shop_types',
#  10760: 'regions_of_the_world',
#  10768: 'home_visit',
#  10770: 'face_control',
#  10782: 'auto_sales',
#  10803: 'goods_for_animals',
#  10804: 'travel_insurance',
#  10824: 'training_duration',
#  10829: 'personal_trainer',
#  10832: 'exercises_for_pregnant_women',
#  10833: 'annual_subscription',
#  10835: 'internet_shop',
#  10836: 'urgent_printing',
#  10840: 'vip_taxi',
#  10843: 'corporate_taxi',
#  10847: 'child_seat',
#  10849: 'courier_delivery',
#  10853: 'ceremonies',
#  10859: 'airport_and_railway_transfers',
#  10870: 'dentist_services',
#  10875: 'show_program',
#  10886: 'music',
#  10888: 'chillout',
#  10894: 'dancefloor',
#  10896: 'dress_code',
#  10898: 'for_kids',
#  10900: 'billiards',
#  10912: 'delivery_medicines',
#  10921: 'trampoline',
#  10966: 'price_per_month2',
#  11006: 'piercing',
#  11012: 'cafe',
#  11022: 'solarium',
#  11032: 'childrens_fitness',
#  11082: 'car_polishing',
#  11097: 'transfer',
#  11106: 'steam',
#  11145: 'entertainment',
#  11165: 'man_haircut',
#  11167: 'tattoo',
#  11172: 'shower',
#  11177: 'breakfast',
#  11187: 'auto_insurance_type',
#  11190: 'number_of_halls',
#  11216: 'pool_tables',
#  11230: 'tire_fitting',
#  11305: 'marktet_types',
#  11389: 'mother_and_child_room',
#  11496: 'number_pool',
#  11531: 'seats',
#  11615: 'photo_studio',
#  11617: 'takeaway',
#  11629: 'summer_terrace',
#  11634: 'free_delivery',
#  11638: 'car_servicing',
#  11642: 'car_wash_type',
#  11657: 'car_waxing',
#  11658: 'tire_blacking',
#  11661: 'wheel_balancing',
#  11663: 'vulcanization',
#  11700: 'aquarium',
#  11703: 'clothes_fitting',
#  11704: 'wi_fi',
#  11705: 'tailoring',
#  11707: 'embroidery',
#  11709: 'strip',
#  11721: 'shooting',
#  11722: 'tailoring_of',
#  11731: 'photo_printing',
#  11741: 'gift_certificate',
#  11758: 'photo_processing',
#  11774: 'price_1_min',
#  11827: 'wide_format_printing',
#  11828: 'riding',
#  11830: 'implants',
#  11832: 'scarification',
#  11834: 'tongue_splitting',
#  11835: 'video_digitization',
#  11836: 'suspension',
#  11838: 'snooker_table',
#  11839: 'delivery',
#  11840: 'tattoo_training',
#  11842: 'wet_cleaning',
#  11843: 'body_art',
#  11847: 'cleaning_services',
#  11848: 'theater_type',
#  11862: 'window_and_glass_cabinet_washing',
#  11864: 'fur_coat_storage',
#  11865: 'extreme_driving',
#  11867: 'business_lunch',
#  11870: 'dress_hire_and_tailoring',
#  11878: 'dresses',
#  11881: 'wedding_planning',
#  11882: 'work_with_individuals',
#  11883: 'additional_services_cars',
#  11886: 'additional_services_gas_station',
#  11895: 'brokencars',
#  11896: 'online_photo_printing',
#  11897: 'spa_services',
#  11904: 'infrared_sauna',
#  11906: 'hydro_massage_pool',
#  11909: 'shopping_advice',
#  11912: 'pilgrimage_service',
#  11913: 'photo_shoot',
#  11915: 'terrariums',
#  11916: 'wardrobe_analysis',
#  11920: 'make_up_style',
#  11930: 'wardrobe_makeover',
#  11933: 'dry_cleaning',
#  11935: 'color_analysis',
#  11936: 'internet_in_hotel',
#  11944: 'individual_training',
#  11948: 'master_classes',
#  11951: 'elevator',
#  11953: 'training_material',
#  11957: 'yoga_for_children',
#  11959: 'number_of_attraction',
#  11961: 'bbq',
#  11963: 'yoga_lesson_programs',
#  11967: 'eye_tests',
#  11968: 'back_treatment',
#  11970: 'fishing',
#  11972: 'yoga_seminars',
#  11977: 'lagoon',
#  11978: 'for_teachers',
#  11981: 'childrens_pool',
#  11982: 'fito_bar',
#  12015: 'opticians_services',
#  12047: 'tour_operators',
#  12048: 'payment_method',
#  12172: 'restorative_program',
#  12174: 'refueling_truck',
#  12178: 'auto_gas_station',
#  12193: 'table_tennis',
#  12195: 'dressing_room',
#  12196: 'insurance_services',
#  12198: 'animation_staff',
#  12200: 'insurance_type',
#  12203: 'rental',
#  12204: 'assortment_of_cake_fillings',
#  12206: 'cakes_for_different_occasions',
#  12209: 'ice_rink',
#  12210: 'corporate_events',
#  12212: 'self_service',
#  12243: 'fuel_cards',
#  12288: 'handicraft_type',
#  12290: 'handicraft_stores',
#  12292: 'type_windows',
#  12294: 'services_windows',
#  12303: 'windows_accessories',
#  12309: 'price_room',
#  20278: 'foregn_language_children',
#  20279: 'basic_service',
#  20280: 'hall_rental',
#  20282: 'price_cup_cappuccino',
#  20283: '4dx',
#  20285: 'cooperation_with_courier_services',
#  20288: 'legal_services_in_housing',
#  20291: 'plugtype',
#  20299: 'sport_place',
#  20303: 'types_motorcycles',
#  20304: 'price_rolls',
#  20305: 'beer_price',
#  20307: 'truck_tire_service',
#  20308: 'mobile_tire_service',
#  20309: 'dry_cleaning_home',
#  20328: 'national_library',
#  20329: 'public_library',
#  20330: 'technical_library',
#  20331: 'special_library',
#  20345: 'payment_by_parkmachine',
#  20346: 'payment_by_app',
#  20365: 'authorized_service',
#  20370: 'types_of_cosmetology',
#  20399: 'sport_activities',
#  20400: 'tires_on_all_wheels',
#  20402: 'classic_female_manicure_coated',
#  20403: 'labor_time',
#  20404: 'garbage_can',
#  20405: 'toilet',
#  20407: 'preliminary_registration',
#  20411: 'the_number_of_places_in_the_room',
#  20422: 'payment_by_credit_card',
#  20424: 'price_category',
#  20440: 'object',
#  20442: 'child_psychologist',
#  20459: 'watch',
#  20461: 'wrist_watch',
#  20490: 'for_cat',
#  20522: 'direction_college',
#  20536: 'level_training',
#  20539: 'form_high_school',
#  20541: 'for_dog',
#  20583: 'privately',
#  20600: 'areas_training',
#  20642: 'bicycle_trips',
#  20643: 'price_rental',
#  20660: 'types_tires',
#  20671: 'tennis_coverage',
#  20703: 'number_lanes',
#  20711: 'cost_hiring',
#  20713: 'car_body_cleaning_cost',
#  20725: 'iceloadingreagents',
#  20730: 'services_individuals',
#  20736: 'registration_liquidation_companies',
#  20742: 'medical_certificate',
#  20745: 'price_bed',
#  20757: 'data_recovery',
#  20779: 'types_wheels',
#  20793: 'medical_diagnostics',
#  20819: 'outdoor_skating_rink',
#  20850: 'preparatory_courses',
#  20853: 'nail_artdesign',
#  20854: 'parking_tariff',
#  20864: 'anonymous_medical',
#  20875: 'medical_specialists',
#  20877: 'types_heating_systems',
#  20880: 'hogh_school_ownship',
#  20881: 'weapons',
#  20896: 'types_massage',
#  20915: 'keep_tires',
#  20939: 'manicure_bin',
#  20987: 'research_library',
#  20988: 'fitness_services',
#  21001: 'library_blind',
#  21025: 'school_direction',
#  21032: 'sport',
#  21050: 'car_repairs',
#  21063: 'specialization_clinic',
#  21068: 'school_uniform',
#  21074: 'balancerental',
#  21079: 'sport_painball',
#  21083: 'types_of_print',
#  21100: 'urgent_photo',
#  21109: 'indoor_skating_rink',
#  21110: 'types_roofing_materials',
#  21118: 'creche',
#  21121: 'night_paintball',
#  21131: 'school_paintball',
#  21149: 'sports_rent',
#  21174: 'express_delivery',
#  21177: 'photo_lab',
#  21181: 'beauty_services',
#  21186: 'open_courts_number',
#  21199: 'pedicure_bin',
#  21200: 'specialized_schools',
#  21210: 'boutique',
#  21216: 'organic_food',
#  21238: 'per_first_hour',
#  21247: 'sports_broadcasts',
#  21275: 'kinds_of_cars',
#  21299: 'pc_brand',
#  21305: 'legal_entities',
#  21319: 'music_profession',
#  21322: 'holding_tournaments',
#  21323: 'range_bike',
#  21328: 'speech_therapist',
#  21346: 'type_clock',
#  21366: 'wholesale',
#  21376: 'flour',
#  21379: 'brand_mobile',
#  21380: 'wedding_floristry',
#  21397: 'style_men',
#  21451: 'paid',
#  21462: 'winter_paintball',
#  21506: 'nail_extension_2',
#  21530: 'video_shooting',
#  21535: 'sport_school_type',
#  21546: 'free',
#  21568: 'autovinil',
#  21576: 'interior_partitions',
#  21607: 'regional_library',
#  21615: 'age_category',
#  21618: 'metal_items_repair',
#  21619: 'types_paintball_sites',
#  21620: 'type_paintball',
#  21644: 'indoor_courts_number',
#  21657: 'subscription',
#  21662: 'tire_services',
#  21707: 'vaccination',
#  21720: 'additional_services_shooting',
#  21721: 'medical_clothing',
#  139550717: 'reconstruction_year',
#  139550722: 'beach_line',
#  139550723: 'children_playground',
#  144134373: 'emergency_gas_service',
#  144134379: 'servicing_vip_clients',
#  144134385: 'aluminum_composite_panels',
#  144134386: 'forklift_trucks',
#  144134388: 'services_for_individuals',
#  144134398: 'asbestos',
#  144134399: 'repair_of_clothing',
#  144134401: 'anti_corrosion_treatment',
#  144134411: 'geodetic_works',
#  144134413: 'geological_surveying',
#  144134414: 'types_household_appliances',
#  261704114: 'limited_access',
#  261948609: 'homeopaths',
#  262454212: 'childrens_music_school',
#  262726483: 'automotive_parts',
#  263427293: 'barbecue_rent',
#  263427294: 'picnic_area',
#  263622858: 'on_beach',
#  270844457: 'conferencing_systems',
#  270844458: 'confectionary_equipment',
#  270844459: 'refuse_and_street_sweeping_vehicles',
#  270844460: 'cat_fanciers_club',
#  270844461: 'dog_club',
#  273283228: 'types_of_foods',
#  273469383: 'coffee_to_go',
#  273469384: 'running_club',
#  273726619: 'monitor_repair',
#  273863372: 'dairy_equipment',
#  273863373: 'meat_processing_equipment',
#  273863374: 'lightening_rods',
#  273863375: 'business_telephone_system',
#  273863377: 'metal_tableware',
#  273863378: 'glass_furniture',
#  273863379: 'outboard_motors',
#  273863380: 'medical_glass',
#  274202565: 'ice_cream_production_equipment',
#  274202566: 'brick_production_equipment',
#  274202567: 'real_estate_abroad',
#  275672861: 'hall_for_women',
#  277103989: 'disability_organization',
#  277103990: 'cranes',
#  277103991: 'veterans_organization',
#  279023801: 'insulation_types',
#  279198317: 'available_for_animals',
#  279198318: 'nudist_beach',
#  282978247: 'frameless_furniture',
#  283100856: 'educational_literature',
#  283679224: 'cement_production_equipment',
#  283780512: 'trading_show_windows',
#  283780513: 'monument_protection_and_restoration',
#  284707111: 'handmade_goods',
#  284787817: 'spirits',
#  284787818: 'fish_processing_equipment',
#  284787819: 'types_of_advertising',
#  285289832: 'mccafe',
#  285289833: 'mcauto',
#  285360299: 'appliance_repair',
#  285390725: 'backpacks',
#  285491484: 'orthopedic_shoes',
#  285491485: 'footwear_types',
#  285979812: 'electric_motor_repairs',
#  286637396: 'glassware',
#  286637397: 'surge_protectors',
#  286637399: 'construction',
#  286760671: 'kinds_electronics',
#  290008589: 'ultrasonic_equipment',
#  290008590: 'transformers',
#  310972649: 'management_consulting',
#  310972650: 'baking_equipment',
#  340529552: 'loyalty_card',
#  343097186: 'porcelain',
#  343400806: 'banners',
#  357035380: 'arrangement_of_fountains_and_water_bodies',
#  370891644: 'polymer_piping_systems',
#  370891875: 'protection_of_copyrights',
#  370891876: 'civil_engineering',
#  370891877: 'investment_and_development_organization',
#  370891878: 'refrigerated_transport',
#  411925571: 'cards_and_envelopes',
#  414319396: 'sky_lights',
#  421346942: 'cctv',
#  421346943: 'offices_for_rent',
#  421346944: 'rent_apartments',
#  812162416: 'service_of_carpet_cleaning',
#  840026754: 'hockey_playground',
#  840026755: 'hockey_school',
#  840026756: 'figure_skating_school',
#  840026757: 'coating_roller',
#  856448080: 'public_bath',
#  856448081: 'detectors_of_banknotes',
#  856448082: 'money_counters',
#  948581684: 'office_or_warehouse',
#  956707375: 'construction_and_design_organization',
#  976365376: 'postpay1',
#  976365377: 'high_speed_fuel_dispenser',
#  1010409666: 'stoloto',
#  1076799212: 'mcexpress',
#  1082283206: 'features_institution',
#  1116173085: 'vocal_lessons',
#  1116173086: 'around_the_clock_work1',
#  1116173087: 'self_service_kiosks',
#  1189498238: 'food_court1',
#  1602431352: 'diesel_service',
#  2020795524: 'craft_beer',
#  2995866956: 'removing_dents_without_painting',
#  3013110545: 'for_disabled_people',
#  3481212270: 'vehicle_category',
#  3481212271: 'electricity_costs',
#  3483661991: 'burger_king_cafe',
#  3483661992: 'burger_king_auto',
#  3483661993: 'kfc_cafe',
#  3483661994: 'kfc_auto',
#  3483778357: 'subscription_fee',
#  3483778358: 'parking_24h',
#  3483837590: 'parking_price',
#  3484586475: 'confession',
#  3485375347: 'gyno_cost',
#  3485438928: 'ultrasound_price',
#  3491142672: 'parking_disabled',
#  3491465406: 'privilege_tickets',
#  3491465421: 'privilege_haircut',
#  3491580623: 'hire_price_day',
#  3491623595: 'bike_rental_rate',
#  3491713232: 'doctor home visit',
#  3492024821: 'without_address',
#  3492120803: 'new_building',
#  3492120822: 'elite_real_estate',
#  3492121086: 'country_estate',
#  3492176323: 'operator_id',
#  3493051166: 'ssid',
#  3493268424: 'barbershop',
#  3500005740: 'only_pre_order',
#  3501410074: 'azs_number',
#  3501410396: 'azs_flag',
#  3501424584: 'unit_id',
#  3501471642: 'business lunch price',
#  3501471649: 'pvc boats',
#  3501474505: 'price_room_hour',
#  3501480642: 'has_bar',
#  3501480644: 'has_conference_halls',
#  3501480645: 'territory_size',
#  3501480656: 'kids_pool',
#  3501481353: 'projector',
#  3501481355: 'number of screens',
#  3501481491: 'free shuttle',
#  3501482162: 'icon',
#  3501488776: 'quests types',
#  3501492237: 'laser gravure',
#  3501497890: 'hard cover',
#  3501498182: 'rooms with soundproofing',
#  3501498183: 'aquapark',
#  3501498184: 'hairdryer',
#  3501498186: 'kitchen in the room',
#  3501498187: 'shared kitchen',
#  3501498188: 'tea coffee in rooms',
#  3501498189: 'TV in room',
#  3501498190: 'bathhouse',
#  3501498191: 'business center',
#  3501498193: 'hammam',
#  3501498194: 'babysitting service',
#  3501498195: 'jacuzzi',
#  3501498196: 'bathrobe',
#  3501498197: 'slippers',
#  3501498198: 'washing machine',
#  3501498199: 'iron',
#  3501498200: 'cleaning',
#  3501498201: 'childrens club',
#  3501498202: 'ski equipment hire',
#  3501498203: 'ski storage space',
#  3501498204: 'ski to door access',
#  3501498205: 'sale of ski pass',
#  3501498206: 'mandatory deposit',
#  3501498207: 'adults only',
#  3501498208: 'lgbt friendly',
#  3501498209: 'heating',
#  3501498210: 'combined rooms',
#  3501498211: 'deckchairs',
#  3501498212: 'beach umbrella',
#  3501498213: 'beach towels',
#  3501498214: 'free umbrellas deckchairs',
#  3501498215: 'veranda terrace patio',
#  3501498216: 'beach bar',
#  3501498217: 'ventilator',
#  3501498218: 'rooms for smokers',
#  3501498367: 'mortage',
#  3501498368: 'decoration',
#  3501498369: 'econom',
#  3501498370: 'developer',
#  3501498371: 'number of bars',
#  3501498372: 'number of restaurants',
#  3501498379: 'internet access',
#  3501498382: 'parking type',
#  3501498389: 'free transfer',
#  3501498568: 'around the clock front desk',
#  3501498569: 'public area',
#  3501498588: 'sports types',
#  3501500016: 'hotel_type_tech',
#  3501501061: '1c software',
#  3501501062: 'non smoking rooms',
#  3501501063: 'private beach',
#  3501501064: 'room service',
#  3501501235: 'ping pong',
#  3501502225: 'wired_internet',
#  3501503649: 'goods delivery',
#  3501509021: 'meeting room',
#  3501509022: 'shared toilet',
#  3501509023: 'poolside bar',
#  3501509024: 'fireplace',
#  3501509025: 'valet parking',
#  3501509026: 'game room',
#  3501509027: 'waterslides',
#  3501509028: 'parking for yachts',
#  3501509029: 'electric car charging station',
#  3501509030: 'express check in out',
#  3501509031: 'evening entertainment',
#  3501509032: 'doctor',
#  3501509033: 'butler',
#  3501509034: 'pharmacy',
#  3501509035: 'ski school',
#  3501509037: 'gaming house',
#  3501509041: 'type of transfer',
#  3501509042: 'safe',
#  3501509045: 'safe type',
#  3501509475: 'bath',
#  3501509914: 'check in',
#  3501509940: 'check out',
#  3501510638: 'forensic examination',
#  3501513153: 'tag_menu',
#  3501519747: 'ems training',
#  3501522239: 'sensitive',
#  3501525722: 'mental arithmetic',
#  3501534098: 'ice rental',
#  3501539205: 'vinotheque',
#  3501543756: 'materials for nails',
#  3501546132: 'loan secured by real estate',
#  3501547180: 'type of animal',
#  3501549616: 'tag_beauty',
#  3501549733: 'tag_medicine',
#  3501549840: 'tag_auto',
#  3501566088: 'cinder blocks',
#  3501567639: 'literature for children',
#  3501569758: 'motorcycle brands',
#  3501572104: 'classes for children',
#  3501577089: 'europallets',
#  3501583166: 'free consultation',
#  3501583611: 'modular cargo',
#  3501583614: 'long distance taxi',
#  3501583622: 'dental treatment in installments',
#  3501583627: 'mens spa',
#  3501583680: 'cosmetology for men',
#  3501583907: 'manual alert systems',
#  3501583920: 'tattoo removal',
#  3501583942: 'turbine repair',
#  3501586968: 'land management expertise',
#  3501586983: 'montessori',
#  3501587292: 'free examination',
#  3501587293: 'preparation for exam',
#  3501594247: 'design of the fountains',
#  3501596642: 'tobacco labeling',
#  3501599455: 'cryosauna',
#  3501599535: 'facilities for disabled people',
#  3501599537: 'slot machines',
#  3501599538: 'hairdresser',
#  3501599541: 'menu for children',
#  3501599543: 'baby cots',
#  3501599554: 'kitchen equipment',
#  3501599561: 'hotel garden',
#  3501599563: 'vineyard',
#  3501599566: 'vending machines with snacks',
#  3501599567: 'garage',
#  3501599570: 'hire',
#  3501599571: 'concierge service',
#  3501599572: 'banquet hall',
#  3501599575: 'doorman',
#  3501599585: 'business center equipment',
#  3501599586: 'allergy free room',
#  3501599587: 'number of meeting rooms',
#  3501599588: 'disco',
#  3501599593: 'theater',
#  3501599594: 'ice rink',
#  3501599597: 'wine tasting',
#  3501599603: 'cleaning frequency',
#  3501599604: 'health centre',
#  3501599610: 'bellboy',
#  3501599676: 'animal accommodations',
#  3501599677: 'animal care',
#  3501599682: 'animals allowed to be accommodated',
#  3501599691: 'restrictions on living with animals',
#  3501604484: 'wax seals',
#  3501604516: 'gastronorm containers',
#  3501604850: 'moto equipment',
#  3501604974: 'paper package',
#  3501610669: 'tillers',
#  3501611178: 'galvanized beds',
#  3501613146: 'types of electrical products',
#  3501613588: 'photo_retouching',
#  3501616848: 'hotel_price_category',
#  3501616913: 'welding_works',
#  3501618484: 'wheelchair_access',
#  3501619158: 'alcohol_license',
#  3501619188: 'repair_knitwear',
#  3501620046: 'bubble_film',
#  3501621367: 'kinesis_training',
#  3501621377: 'agronavigators',
#  3501621378: 'parallel_driving_systems',
#  3501621382: 'cups_medals',
#  3501621388: 'drones_quadcopters',
#  3501621391: 'chipboard_cutting',
#  3501623871: 'cigars_cigarillos',
#  3501626676: 'motorcycle_tire_repair',
#  3501626694: 'aerocrete',
#  3501627295: 'onsite_diagnostics_cars',
#  3501629404: 'repair_of_refrigerated_trucks',
#  3501631840: 'gift_wrapping',
#  3501631894: 'tax_free',
#  3501637468: 'level',
#  3501637602: 'self_car_service',
#  3501638584: 'field_repair_of_phones',
#  3501638601: 'flowers_in_flask',
#  3501639433: 'karting_prices',
#  3501640731: 'foodcourt',
#  3501640735: 'plotter_cutting',
#  3501640737: 'only_under_order',
#  3501643038: 'transport_refrigeration_equipment',
#  3501643039: 'anti_gravity_film',
#  3501643040: 'caviar_store',
#  3501647385: 'dress_hire',
#  3501649263: 'auto_generated_food_filter',
#  3501652258: 'mens_nail_services',
#  3501656640: 'fight_club',
#  3501656641: 'calculation_of_insolation',
#  3501657208: 'rating_of_moscow_schools',
#  3501668257: 'sweet_gifts',
#  3501674400: 'breakfast_included',
#  3501674401: 'free_cancellation',
#  3501674501: 'brand_office_equipment',
#  3501675316: 'farm_products',
#  3501677065: 'vinyl',
#  3501677091: 'registration_of_medical_devices',
#  3501678436: 'coaching',
#  3501679779: 'aquaprint',
#  3501679846: 'purchase_of_radio_components',
#  3501680348: 'medical_pedicure',
#  3501682169: 'vintage_clothing',
#  3501682201: 'self_storage_warehouse',
#  3501682216: 'night_groups',
#  3501682700: 'excursions_for_schoolchildren',
#  3501684957: 'hair_transplantation',
#  3501685156: 'table_games',
#  3501687599: 'storage_of_motorcycles',
#  3501689802: 'repair_of_game_consoles',
#  3501689804: 'quadcopter_repair',
#  3501692956: 'bio_cleaning',
#  3501693369: 'flight_simulator',
#  3501694289: 'teahouse',
#  3501694323: 'goods_for_bakery',
#  3501694325: 'cedar_barrel',
#  3501694353: 'builtin_appliances',
#  3501700359: 'freight_car_service',
#  3501703400: 'courses_for_elderly',
#  3501704145: 'crm_implementation',
#  3501707180: 'type_of_deal',
#  3501707183: 'rental_period',
#  3501707201: 'assessment_qualification_employees',
#  3501708144: 'accommodation_type',
#  3501708666: 'wine_tasting',
#  3501710354: 'indoor-plan-id',
#  3501710419: 'dancing_for_beginners',
#  3501710426: 'extended_day_group',
#  3501711656: 'disposable_clothing',
#  3501711661: 'products_for_hairdressers',
#  3501712327: 'earpieces',
#  3501713908: 'baby_massage',
#  3501715376: 'hatches',
#  3501721033: 'equipment_for_tattoo',
#  3501721629: 'air_walks',
#  3501722842: 'iqos_repair',
#  3501725224: 'transportation_storage_dangerous_goods',
#  3501725225: 'spare_parts_for_restaurant_equipment',
#  3501727103: 'pressure_chamber',
#  3501729440: 'repurchase_of_insurance_debts',
#  3501734268: 'thermobags',
#  3501734280: 'coworking',
#  3501735971: 'large_format_scanning',
#  3501738022: 'gong_meditation',
#  3501738031: 'buying_up_radio_devices',
#  3501739378: 'vr_ar_development',
#  3501739652: 'rating_threshold',
#  3501743496: 'restoration_down_feather_products',
#  3501744275: 'closed_for_quarantine',
#  3501745827: 'food_product_delivery',
#  3501747162: 'cyclorama',
#  3501748140: 'professional_cosmetics',
#  3501749289: 'closed_for_visitors',
#  3501749391: 'payment_from_car',
#  3501751270: 'online_classes',
#  3501751965: 'educational_consulting',
#  3501752548: 'installation_of_acoustic_systems',
#  3501754118: 'led_street_lighting',
#  3501754121: 'industrial_led_lighting',
#  3501754799: 'pickup',
#  3501759226: 'hookah_rental',
#  3501759265: 'types_of_equipment',
#  3501759464: 'cast_iron_cookware',
#  3501765089: 'bread_from_tandoor',
#  3501766414: 'groups_for_adults',
#  3501769429: 'trailer_repair',
#  3501769434: 'coffee_shop',
#  3501769723: 'covid_hotel_safety_air_disinfection',
#  3501769724: 'covid_hotel_safety_sanitizers',
#  3501769725: 'covid_hotel_safety_employees_use_personal_protective_gear',
#  3501769739: 'covid_hotel_safety_thermometry',
#  3501769740: 'covid_hotel_safety_marking_floor',
#  3501769741: 'covid_hotel_safety_isolation',
#  3501769751: 'covid_hotel_safety_placing_tables_at_distance',
#  3501769752: 'covid_hotel_safety_washing_at_high_temperatures',
#  3501769755: 'covid_hotel_safety_barriers',
#  3501769756: 'covid_hotel_safety_сontactless_check_out',
#  3501769757: 'covid_hotel_safety_employee_training',
#  3501769758: 'covid_hotel_safety_сontactless_room_service',
#  3501769759: 'covid_hotel_safety_disinfection_contact_surfaces',
#  3501769760: 'covid_hotel_safety_disinfection_surfaces_rooms',
#  3501769761: 'covid_hotel_safety_disinfection_dining_halls',
#  3501769762: 'covid_hotel_safety_disinfection_storage_facilities',
#  3501769763: 'covid_hotel_safety_disinfection_gyms_and_spa',
#  3501769765: 'covid_hotel_safety_disinfection_equipment_in_open_spaces',
#  3501770296: 'buying_cartridges',
#  3501772560: 'canteen',
#  3501772561: 'childrens_corner',
#  3501773763: 'automatic_door',
#  3501773764: 'toilet_for_disabled',
#  3501773773: 'chip_tuning',
#  3501773799: 'rooms_voicing',
#  3501773817: 'online_broadcasts',
#  3501778442: 'CSP',
#  3501778832: 'gazebo_rental',
#  3501779478: 'online_takeaway',
#  3501779832: 'planter',
#  3501781778: 'military_atelier',
#  3501786035: 'number_of_connectors',
#  3501786036: 'number_of_parking_spaces',
#  3501786039: 'parking_type',
#  3501786471: 'press_for_grapes',
#  3501787643: 'beauty_coworking',
#  3501789292: 'schienalі',
#  3501792408: 'wall_panels',
#  3501793680: 'florarium',
#  3501801715: 'occluders_opticludes',
#  3501803507: 'ferris_wheel',
#  3501806316: 'mansard_windows',
#  3501814557: 'iqos',
#  3501820537: 'new_year_gifts',
#  3501822933: 'free_excursions',
#  3501823885: 'printing_on_cakes',
#  3501827474: 'purchase_of_electronic_devices',
#  3501827489: 'credit_cards',
#  3501833069: 'electronic_registration_of_transactions',
#  3501833418: 'hotel_pansion',
#  3501839524: 'diagnostics_of_animal_diseases',
#  3501844201: 'gas_station_takeaway_shop',
#  3501854477: 'edible_bouquets',
#  3501878443: 'epassport_for_vehicles',
#  3501941331: 'it_services',
#  3501941361: 'virus_prevention',
#  3501941962: 'no_prepayment',
#  3501942001: 'free_measurement',
#  3501942075: 'guarantee',
#  3501942246: 'contract_conclusion',
#  3501942247: 'measuring',
#  3501942249: 'online_consultations',
#  3501942269: 'from_manufacturer',
#  3501942276: 'individual_sizes',
#  3501942279: 'turnkey',
#  3501942284: 'round_the_clock_support',
#  3501942295: 'installment',
#  3501942428: 'promotions',
#  3501945020: 'availability',
#  3501945049: 'processing_speed',
#  3501945100: 'upholstered_furniture',
#  3501945135: 'type_of_furniture',
#  3501948336: 'internet_marketing_services',
#  3501948407: 'real_estate_services',
#  3501961675: 'hotel_city_center_nearby',
#  3501964004: 'hotel_park_nearby',
#  3501964029: 'hotel_airport_nearby',
#  3501964032: 'hotel_sea_nearby',
#  3501964056: 'hotel_city_center_dist_category',
#  3501992267: 'yandex_smart_speaker',
#  3501997364: 'adv_hleb_i_vypecka_produkty_napitki',
#  3502003689: 'closed_for_without_qr',
#  3502010179: 'current_license',
#  3502010332: 'vid_division',
#  3502010539: 'registration_number',
#  3502010548: 'egr',
#  3502010918: 'call_button',
#  3502010929: 'elevator_wheelchair_accessible',
#  3502010932: 'ramp',
#  3502010938: 'wheelchair_accessible',
#  3502023279: 'types_of_bank_activities',
#  3502029228: 'takeout_to_car',
#  3502031788: 'indoor_plants',
#  3502040627: 'data_from_the_CB',
#  3502043655: 'report_upload_date',
#  3502043657: 'legal_name_organization',
#  3502043677: 'abbreviated_name',
#  3502043680: 'tin',
#  3502043705: 'international_name',
#  3502043737: 'meal',
#  3502044048: 'staff',
#  3502044229: 'atmosphere',
#  3502044237: 'cash_register',
#  3502044252: 'registration_process',
#  3502044665: 'food_quality',
#  3502044672: 'goods_quality',
#  3502044685: 'waiting_period',
#  3502044709: 'menu_range',
#  3502044741: 'rooms',
#  3502044748: 'service_quality',
#  3502044801: 'enjoyable_sound',
#  3502044826: 'org_territory',
#  3502044834: 'views',
#  3502045016: 'types_of_delivery',
#  3502045017: 'number_of_tables',
#  3502045032: 'non_cash_tips',
#  3502045280: 'cosy_atmosphere',
#  3502045286: 'romantic_atmosphere',
#  3502045289: 'beautiful_interior',
#  3502045294: 'unusual_interior',
#  3502045301: 'spacious',
#  3502045303: 'small_cafe',
#  3502045309: 'dancings',
#  3502045322: 'panoramic_view',
#  3502045326: 'new_organization',
#  3502045331: 'well_for_dating',
#  3502045336: 'well_for_big_company',
#  3502045340: 'well_for_business_meetings',
#  3502045342: 'well_for_family_dinner',
#  3502045395: 'well_atmosphere',
#  3502045402: 'unusual_concept',
#  3502045411: 'beautiful_serving_of_dishes',
#  3502045433: 'well_for_banquet',
#  3502045496: 'well_with_children',
#  3502045553: 'choice_variety',
#  3502045556: 'democracy',
#  3502045562: 'grill',
#  3502045597: 'foreign_chef',
#  3502045611: 'marriage',
#  3502046291: 'well_for_birthday_party',
#  3502046294: 'corporate_party',
#  3502046330: 'on_roof',
#  3502046337: 'restaurateur',
#  3502046339: 'chef',
#  ...}

# %% [markdown]
# Посмотрим, какими бывают типы заведений:

# %%
rubric_dict = rubrics.set_index('rubric_id')['rubric_name'].to_dict()
rubric_dict
# Out:
# {30519: 'Булочная, пекарня',
#  30770: 'Бар, паб',
#  30771: 'Быстрое питание',
#  30774: 'Кафе',
#  30775: 'Пиццерия',
#  30776: 'Ресторан',
#  30777: 'Столовая',
#  31286: 'Спортбар',
#  31350: 'Кондитерская',
#  31375: 'Суши-бар',
#  31401: 'Кальян-бар',
#  31495: 'Кофейня',
#  3108292683: 'Бар безалкогольных напитков',
#  3501514558: 'Фудкорт',
#  3501750896: 'Кофе с собой'}

# %% [markdown]
# Мы что-то поняли про признаки, которыми нам предстоит пользоваться. Теперь время посмотреть на таргет. Вооружившись функциями ``hist`` и ``scatter`` из библиотеки ``matplotlib``, а также методом ``isna`` для pandas-таблиц разберитесь, какие значения принимают таргеты, есть ли там там выбросы, пропуски или ещё какие-то проблемы.
#
# &nbsp;
#
# <details>
#   <summary>Когда будете готовы, кликните сюда, чтобы посмотреть ответ</summary>
#     <ol>
#       <li>Среди таргетов довольно много пропусков;</li>
#       <li>Все таргеты - это числа, кратные 500;</li>
#       <li>Есть какие-то адские значения, превышающие 100 000 (видимо, выбросы);</li>
#       <li>В целом, число ресторанов с данным средним чеком быстро падает с ростом среднего чека. Для средних чеков, больших 2500, заведений уже совсем мало. Примерно у 2/3 заведений средний чек 500.</li>
#     </ol>
# </details>

# %%
print(data.isna().sum())
data['average_bill'].hist(bins=200)
plt.show()
# Out:
# org_id              0
# city                0
# average_bill    35561
# rating          13731
# rubrics_id          0
# features_id     11049
# dtype: int64

# %% [markdown]
# **Базовая очистка данных**
#
# Раз есть треш, давайте чистить данные.
#
# С пропусками можно бороться по-разному (даже и с пропусками в таргете), но пока мы сделаем самую простую вещь: дропнем все заведения, для которых мы не знаем средний чек.
#
# Уберите из них все заведения, у которых средний чек неизвестен или превышает 2500. Пока есть опасение, что их слишком мало, чтобы мы смогли обучить на них что-нибудь.
#
# **3. (1 балл) Введите в Контест количество заведений, которое у вас получилось после очистки**.
#
# Дальше мы будем работать с очищенными данными.

# %%
filtered = data[data["average_bill"].notna() & (data["average_bill"] <= 2500)]
filtered.shape[0]
# Out:
# 32136

# %% [markdown]
# **4. (1 балл) Посчитайте и введите в Контест разность между средними арифметическими average_bill в кафе Москвы и Санкт-Петербурга. Округлите ответ до целого.**
#
# &nbsp;
#
# <details>
#   <summary>Небольшая подсказка</summary>
#   Примените часто используемый метод groupby.
# </details>

# %%
from scipy import stats

subset = filtered[filtered["rubrics_id"].str.contains(r"\b30774\b", na=False)]

# Subsets
spb_bills = subset.loc[subset["city"] == "spb", "average_bill"]
msk_bills = subset.loc[subset["city"] == "msk", "average_bill"]

# Two-sample t-test
t_stat, p_value = stats.ttest_ind(spb_bills, msk_bills, equal_var=False)  # Welch’s t-test

print("t-statistic:", t_stat)
print("p-value:", p_value)

if p_value < 0.05:
    print("✅ The difference in means is statistically significant.")
else:
    print("❌ No statistically significant difference in means.")
    
avg_spb = spb_bills.mean()
avg_msk = msk_bills.mean()

print("MSK average:", avg_msk)
print("SPB average:", avg_spb)
print("Difference (MSK - SPB):", avg_msk - avg_spb)
# Out:
# t-statistic: -22.11811151026241
# p-value: 1.86857441211541e-106
# ✅ The difference in means is statistically significant.
# MSK average: 781.0807941395052
# SPB average: 638.6771069441583
# Difference (MSK - SPB): 142.40368719534695

# %% [markdown]
# Давайте ещё немного поизучаем данные. Ответьте на вопросы:
#
# 1. Есть ли разница между средними чеками в Москве и Санкт-Петербурге?
# 2. Коррелирует ли средний чек с рейтингом?
# 3. Есть ли разница в среднем чеке между ресторанами и пабами (см. соответствующие типы из ``rubrics``)?
#
# &nbsp;
#
# <details>
#   <summary>Когда будете готовы, кликните сюда, чтобы посмотреть ответ</summary>
#     <ol>
#       <li> целом, да. Вы могли бы сравнить средние (в Москве больше). Этого, конечно, мало для того, чтобы сделать вывод. Нужно проверять какие-то статические критерии, которые изучаются в курсе по статистике и AB-тестированию. В данном случае хорошо работает t-test (функцию ttest_ind из библиотеки scipy.stats).</li>
#       <li>Какая-то корреляция между ними есть но уж больно неубедительная (рекомендуем построим на одном графике boxplot рейтинга по каждому значению среднего чека для визуализации). Конечно, дна становится меньше с ростом среднего чека, но, видимо, в предсказании это особо не используешь;</li>
#       <li>Несомненно, в ресторанах средний чек выше. Это и невооружённым глазом видно, и с помощью критерия Манна-Уитни можно проверить.</li>
#     </ol>
# </details>

# %% [markdown]
# ## Формулируем задачу

# %% [markdown]
# Прежде, чем решать задачу, её надо сформулировать.
#
# **Вопрос первый**: это классификация или регрессия? Подумайте над этим.
#
# &nbsp;
#
# <details>
#   <summary>Когда будете готовы, кликните сюда, чтобы посмотреть ответ</summary>
#     Ответ не столь однозначен, как хотелось бы. С одной стороны, таргет принимает всего четыре значения, и потому это может быть классификацией с 4 классами. С другой стороны, таргеты - это не абстрактные "треугольник", "круг", "квадрат", а вещественные числа, и когда мы вместо 500 предсказываем 2500, это явно хуже, чем вместо 1500 предсказать 2000. В целом, задачу можно решать и так, и так; мы будем смотреть на метрики обеих задач.
# </details>

# %% [markdown]
# **Вопрос второй**: какие метрики мы будем использовать для оценки качества решения? Какие метрики вы предложили бы для этой задачи как для задачи классификации? А для этой задачи, как для задачи регрессии?
#
# &nbsp;
#
# <details>
#   <summary>Когда будете готовы, кликните сюда, чтобы посмотреть ответ</summary>
#
#     Начнём с классификации. Метрика accuracy не очень хороша из-за несбалансированности классов. Действительно, классификатор, который всегда говорит 500, будет иметь accuracy примерно 0.66, хотя это никак не отражает практическую ценность модели. Как мы увидим, самая большая проблема будет заключаться в том, чтобы научиться выделять заведения с большими чеками, а их меньше всего и в accuracy они вносят самый маленький вклад. Есть разные способы с этим бороться, один -- использовать sklearn.metrics.balanced_accuracy_score. Его идея, грубо говоря, в том, чтобы по каждому классу найти, какая доля объектов этого класса правильно классифицирована, а потом эти доли усреднить. Тогда у бессмысленного классификатора, который всем ставит 500, будет скор 1/5 (ведь классов 5), а чтобы получить прежние 2/3, нужно будет научиться в каждом классе правильно ставить хотя бы 2/3 меток.
#
#     Теперь что касается регрессии. Основых метрики две - MSE и MAE. Из первой стоит извлекать корень, чтобы получать интерпретируемые человеком значения, а вторая менее агрессивна к выбросам (впрочем, выбросов тут уже нет, мы их все выкинули). Без дополнительной информации не очень понятно, какую выбирать, можно брать любую. А выбирать надо: ведь даже банальные модели "предсказывай всегда среднее" и "предсказывай всегда медиану" будут по-разному ранжироваться этими метриками.
#
# </details>

# %% [markdown]
# **Вопрос третий**: а не взять ли нам какую-нибудь более экзотическую метрику? Например, MAPE (определение в учебнике в главе про оценку качества моделей). А как вам такое соображение: допустим, заказчик говорит, что пользователи будут расстраиваться, только если мы завысили средний чек - так давайте поправим MSE или MAE, обнуляя те слагаемые, для которых предсказанный таргет меньше истинного. Вот это хорошая метрика или нет?
#
# &nbsp;
#
# <details>
#   <summary>Когда будете готовы, кликните сюда, чтобы посмотреть ответ</summary>
#
#     Что касается MAPE, у нас нет тех проблем, с которой она борется. Вот если бы у нас были средние чеки от 500 до миллиона, мы бы столкнулись с ситуацией, что большие ошибки для больших чеков доминировали бы в сумме для MSE и MAE (500 вместо 1000 меркнет по сравнению с 500к вместо миллиона). Говоря поэтически, мы бы оптимизировали модель для миллионеров, забыв про простых трудяг. И было бы логично перейти от парадигмы "ошибаемся на 500 рублей" к парадигме "ошибаемся на 50%". Но у нас все таргеты примерно одного порядка, MAPE нам особо ни к чему.
#
#     Вторая метрика коварна тем, что её можно "накрутить" безо всякой пользы для дела. А именно, модель, которая всегда предсказывает средний чек в миллион, была бы идеальна. Но все бы расстраивались и не ходили есть. Другое дело, что можно ввести разные веса для ошибок в большую и в меньшую сторону, но опять же - пока нет показаний к тому, что это нужно.
#
# </details>

# %% [markdown]
# ## Применяем ML

# %% [markdown]
# Теперь время разбить данные на обучающую и тестовую выборку. Делается это с помощью функции ``train_test_split`` из пакета ``sklearn``. При этом очень важно сделать две вещи:
#
# * Зафиксировать ``random_state=42`` (да, именно этот, а то ваши модели могут не зайти в Контест), чтобы всё, что мы делаем, было воспроизводимо (иначе от перезапуска к перезапуску числа могут меняться, и мы не будем понимать, из-за чего это происходит).
# * Сделать стратификацию по таргету. В противном случае у нас в трейне и тесте могут оказаться разные пропорции классов (обычно особенно страдают мало представленные классы), что неутешительно скажется на результате.
#
# **Обратите внимание**, что если вы побьёте выборку на train и test по-другому, ваши результаты могут не зайти в контест.

# %%
clean_data_train, clean_data_test = train_test_split(
    filtered, stratify=filtered['average_bill'], test_size=0.33, random_state=42)

clean_data_train["modified_features"] = (
    clean_data_train["rubrics_id"].astype(str) 
    + " q " + 
    clean_data_train["features_id"].astype(str)
)

# множество допустимых комбинаций
train_combos = set(clean_data_train["modified_features"].unique())

# test: склеиваем
clean_data_test["modified_features"] = (
    clean_data_test["rubrics_id"].astype(str) 
    + " q " + 
    clean_data_test["features_id"].astype(str)
)

# заменяем всё, чего нет в train
clean_data_test.loc[
    ~clean_data_test["modified_features"].isin(train_combos),
    "modified_features"
] = "other"

# %% [markdown]
# Теперь нам нужен **бейзлайн** - очень простая модель, с которой мы в дальнейшем будем сравниваться.
#
# Поскольку мы ещё не знаем никаких умных классов моделей, все модели мы будем писать руками. А именно, мы напишем две простых модели на основе ``sklearn.baseRegressorMixin`` и ``sklearn.base.ClassifierMixin`` (посмотрите примеры в документации sklearn и сделайте так же):
#
# * Модель для задачи регрессии, которая для всех заведений предсказывает одно число — среднее значение среднего чека;
# * Модель для задачи классификации, которая для всех заведений предсказывает один класс — самый частый класс (ироничным образом он в данном случае совпадает с медианой).
#
# **Важно!** Мы будем много раз повторять вам мантру о том, что **информация из тестовой выборки не должна протекать в процесс обучения**. Так вот, и среднее, и самый частый класс вы должны считать именно на обучающей выборке!
#
# **5 и 6. (по 1 баллу) Напишите эти две модели и сдайте в Контест**. В процессе проверки модели будут и обучаться, и предсказывать.
#
# Заметим, что для этих моделей нам вообще не нужны какие-то "фичи"; мы работаем только с таргетом.
#
# У каждой модели есть (как минимум) два метода: `fit` (обучает модель по фичам `X` и таргету `y`) `predict` (предсказывает по фичам `X`)

# %%
from scipy.stats import mode

from sklearn.base import RegressorMixin

class MeanRegressor(RegressorMixin):
    def fit(self, X=None, y=None):
        y_arr = np.asarray(y)
        self.mean_ = float(np.mean(y_arr))
        return self

    def predict(self, X=None):
        n_samples = np.asarray(X).shape[0]
        return np.full(shape=(n_samples,), fill_value=self.mean_, dtype=float)
        
from sklearn.base import ClassifierMixin
from sklearn.utils.validation import check_is_fitted

class MostFrequentClassifier(ClassifierMixin):
    def fit(self, X=None, y=None):
        y_arr = np.ravel(y)
        labels, counts = np.unique(y_arr, return_counts=True)
        self.most_common_ = labels[np.argmax(counts)]
        return self

    def predict(self, X=None):
        n_samples = np.asarray(X).shape[0]
        return np.full(shape=(n_samples,), fill_value=self.most_common_)

# %% [markdown]
# Обучим наши модели

# %%
reg = MeanRegressor()
reg.fit(y=clean_data_train['average_bill'])

clf = MostFrequentClassifier()
clf.fit(y=clean_data_train['average_bill'])

from sklearn.metrics import mean_squared_error, balanced_accuracy_score

# --- Predict on test set ---
y_test = clean_data_test['average_bill']

# Mean Regressor predictions
y_pred_reg = reg.predict(y_test)   # input shape must match, here just pass y_test

# Most Frequent Classifier predictions
y_pred_clf = clf.predict(y_test)

# --- Compute metrics ---
reg_rmse = np.sqrt(mean_squared_error(y_test, y_pred_reg))

# Balanced accuracy for classification
clf_rmse = np.sqrt(mean_squared_error(y_test, y_pred_clf))
clf_acc = balanced_accuracy_score(y_test, y_pred_clf)

print(f"RMSE (MeanRegressor): {reg_rmse:.4f}")
print(f"RMSE (MostFrequentClassifier): {clf_rmse:.4f}")
print(f"Balanced Accuracy (MostFrequentClassifier): {clf_acc:.4f}")
# Out:
# RMSE (MeanRegressor): 448.7144
# RMSE (MostFrequentClassifier): 514.7517
# Balanced Accuracy (MostFrequentClassifier): 0.2000

# %% [markdown]
# Обучите модели и оцените их качество на тестовой выборке. В качестве метрик возьмём RMSE (``np.sqrt`` от ``sklearn.metrics.mean_squared_error``) и ``sklearn.metrics.balanced_accuracy_score``.
#
# Для регрессионной модели имеет смысл считать только RMSE (значения будут не кратны 500, точно мы угадывать не будем никогда), а вот для классификационной можно найти обе метрики. Сделайте это. Какая модель оказалась лучше по RMSE?

# %% [markdown]
# <details>
#   <summary>Когда будете готовы, кликните сюда</summary>
#
#   Казалось бы, регрессор никогда не угадывает, но он в каком-то смысле лучше классификатора - справедливо ли это? Возможно. Несуществующий пользователь модели вряд ли будет задавать вопросы "почему средний чек не кратен 500?" Ну, выдали около 800 - ок, понятно.
#
# </details>

# %% [markdown]
# ## Усложнение модели

# %% [markdown]
# Бейзлайны будут нашей отправной точкой. Строя дальнейшие модели, мы будем спрашивать себя: получилось ли лучше бейзлайна? Если нет или если не особо, то в чём смысл усложнения?

# %% [markdown]
# Начнём с использования фичи ``city``. Мы уже видели, что в разных городах и средние чеки разные. Легко проверить, что *медиана* средних чеков всё же одна и та же и в Москве, и в Санкт-Петербурге (ох уж этот вездесущий средний чек 500!), поэтому с классификатором мы ничего не сделаем. Но вот регрессор можно попробовать починить.
#
# **7. (1 балл) Напишите регрессор, для каждого заведения предсказывающий среднее значение в том же городе (на обучающей выборке, конечно) и сдайте его в Контест**. Вам может помочь то, что булевы `pandas` и `numpy` столбцы можно умножать на численные — в такой ситуации False работает, как ноль, а True как единица.

# %%
from sklearn.base import RegressorMixin

class CityMeanRegressor(RegressorMixin):
    def fit(self, X=None, y=None):
        y_arr = np.asarray(y)
        cities = np.asarray(X['city'])

        # Compute per-city mean
        # Convert city labels to strings (msk/spb), keeping None/NaN as is for later handling
        cities_clean = np.asarray(cities)

        city_means = {}
        unique_cities = []
        for city in np.unique(cities_clean):
            if city is None or (isinstance(city, float) and np.isnan(city)):
                continue
            mask = (cities_clean == city)
            if np.any(mask):
                city_means[str(city)] = float(np.mean(y_arr[mask]))
                unique_cities.append(str(city))

        self.city_means_ = city_means
        self.cities_ = np.array(unique_cities, dtype=object)

        return self

    def predict(self, X=None):
        cities = np.asarray(X['city'])

        preds = np.empty(len(cities), dtype=float)
        for i, c in enumerate(cities):
            preds[i] = self.city_means_.get(str(c), 0)

        return preds

# %% [markdown]
# Обучите регрессор и сравните его по метрике RMSE с бейзлайнами. Получилось ли улучшить метрику?

# %% [markdown]
# Лучше стало, но, правда, не очень сильно. В этот момент очень важно не просто радовать руководителя приростом в третьем знаке, но и думать о том, что происходит.
#
# Средний средний чек по Москве равен 793, в Санкт-Петербурге - 676, а в целом - 752 рубля. MSE, увы, не поможет вам ответить на вопрос, стало ли лучше пользователю, если вы ему вместо 752 рублей назвали 793. Здесь вскрывается весьма существенный порок MSE в этой задаче. Дело в том, что наш изначальный таргет делит заведения на некоторые "ценовые категории", и различие в средних чеках 500 и 1000 в самом деле существенно. Наверное, мы хотели бы как раз правильно предсказывать ценовые категории. Но MSE не очень помогает нам об этом судить. Дальше мы ещё подумаем, как это исправить.
#
# В любом случае, несмотря на улучшение метрики, мы пока не можем судить, стало ли по жизни лучше от усложнения модели.

# %% [markdown]
# Поручинившись немного, возьмём на вооружение другую идею. Давайте использовать типы заведений!
#
# Но с типами есть некоторая проблема: в столбце ``rubrics_id`` не всегда один идентификатор, часто их несколько, и всего комбинаций довольно много. Чтобы не возиться с малочисленными типами, давайте сольём их в один безликий ``other``.
#
# Итак, добавьте в обучающие и тестовые данные столбец ``modified_rubrics``, в котором будет то же, что и в ``rubrics_id``, если соответствующая комбинация рубрик содержит хотя бы 100 заведений из обучающей (!) выборки, и строка ``other`` в противном случае.
#
# Здесь вам поможет контейнер ``Counter`` из библиотеки ``collections``.

# %%
# your code

# %% [markdown]
# Теперь настало время написать могучий классификатор, который по заведению предсказывает медиану средних чеков среди тех в обучающей выборке, у которых с ним одинаковые `modified_rubrics` и город (вы спросите, почему медиану, а не самый частый -- спишем это на вдохновение; самый частый тоже можно брать - но медиана работает лучше).
#
# **8. (2 балла) Напишите классификатор и сдайте в Контест**.

# %%
from sklearn.base import ClassifierMixin
import numpy as np

class MostFrequentClassifier(ClassifierMixin):
    def fit(self, X=None, y=None):
        y_arr = np.ravel(y)
        labels, counts = np.unique(y_arr, return_counts=True)
        self.most_common_ = labels[np.argmax(counts)]
        return self

    def predict(self, X=None):
        n_samples = np.asarray(X).shape[0]
        return np.full(shape=(n_samples,), fill_value=self.most_common_)

# %% [markdown]
# Сравните обученный классификатор по метрикам RMSE и balanced_accuracy_score с нашими бейзлайнами. Получилось ли улучшить?

# %% [markdown]
# Обратите внимание что рост accuracy по сравнению с бейзлайном при этом на порядок меньше:

# %% [markdown]
# accuracy_score
#
# Predict most frequent:  0.6947666195190948
#
# Predict by rubric and city:  0.7095709570957096

# %% [markdown]
# Для диагностики напечатайте для каждого класса тестовой выборки, сколько в нём объектов и скольким из них наш классификатор приписал правильный класс. Что вы видите?
#
# &nbsp;
#
# <details>
#   <summary>Когда будете готовы, кликните сюда, чтобы посмотреть ответ</summary>
#
#   Вы, вероятно, видите то, что мы стали однозначно лучше по сравнению с бейзлайном детектировать средний чек 1000 и 1500 (хотя всё равно не очень хорошо + ценой ухудшения качества на среднем чеке 500), а вот чеки 2000 и 2500 нам ну никак не даются.
#
# </details>

# %% [markdown]
# **Кстати**. А вы понимаете, почему приведённый выше пайплайн классификации был не очень удачным с точки зрения архитектуры? Почему его было бы правильнее воплотить по-другому?
#
# &nbsp;
#
# <details>
#   <summary>Когда будете готовы, кликните сюда, чтобы посмотреть ответ</summary>
# Собственно говоря, и не было никакого пайплайна. К счастью, у нас была одна обучающая выборка, мы на ней посчитали список рубрик для modified_rubrics и радовались жизни. Но если бы нам надо было переобучать всё на новых данных, пришлось бы помнить, что их надо везде пересчитать (ведь у нас могли появиться новые рубрики с хотя бы 100 представителями). А уж никакую кросс-валидацию (кто знает - тот поймёт) с нашим подходом к делу и вовсе бы не получилось сделать без боли.
#
# Поэтому в следующей лабораторной вы научитесь делать честные пайплайны, в которых преобразование данных, генерация фичей и обучение классификатора будут объединены в один понятный процесс, происходящий на этапе fit.
# </details>

# %% [markdown]
# ## Слишком простые и слишком сложные модели

# %% [markdown]
# Бейзлайны у нас слишком просты и потому не очень полезны в жизни. Но если сложность модели растёт бесконтрольно, то тоже получается плохо.
#
# Давайте рассмотрим конкретный пример. Создадим классификатор, использующий одновременно `rubrics_id` и `features_id`.
#
# Сделайте следующее:
#
# - для каждого объекта обучающей выборки сконкатенируйте строку `rubrics_id` с разделителем (например, буквой 'q') и содержимым `features_id`. Полученный столбец озаглавьте `modified_features`. Это не самый клёвый способ заиспользовать все фичи, но сейчас пока сойдёт. Причём на сей раз не будем выкидывать мало представленные значения (вся информация важна, не так ли?).
# - при этом для тестовой выборки заменяйте на строку `other` все конкатенации, которые не встретились в обучающей выборке.
#
# То есть элементы в этом столбце будут иметь вид `other` или `30776 30774 q 3502045032 11741 3502045016 1046...`.

# %% [markdown]
# Теперь обучите классификатор, который для заведения предсказывает медиану среднего чека по всем объектам тестовой выборки с таким же, как у него, значением `modified_features`, а если такого в обучающей выборке нет, то глобальную медиану среднего чека по всей обучающей выборке.
#
# **9. (2 балла) Загрузите в Контест предсказания этого классификатора на тестовой выборке**
#
# Мы ждём файла **.csv**, у которого в каждой строке будет только одно число - предсказание классификатора.
#
# Возможно, вам будет полезна библиотека ``tqdm``, позволяющая отслеживать в реальном времени, сколько времени уже крутится цикл и сколько итераций ещё осталось. Впрочем, если вы всё написали нормально, то должно работать не очень долго.

# %%
from sklearn.base import BaseEstimator, ClassifierMixin

class ModifiedFeaturesMedianClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self):
        self.medians_ = None
        self.global_median_ = None

    def fit(self, X, Y):
        if isinstance(X, pd.DataFrame):
            mf = X["modified_features"].reset_index(drop=True)
        elif isinstance(X, pd.Series):
            mf = X.reset_index(drop=True)
        else:
            mf = pd.Series(np.asarray(X).ravel(), name="modified_features")

        y = pd.Series(np.asarray(Y).ravel(), name="mean_receipt")

        df = pd.concat([mf, y], axis=1)

        self.medians_ = df.groupby("modified_features")["mean_receipt"].median().to_dict()
        self.global_median_ = float(y.median())

        return self

    def predict(self, X):
        if isinstance(X, pd.DataFrame):
            mf = X["modified_features"]
        elif isinstance(X, pd.Series):
            mf = X
        else:
            mf = pd.Series(np.asarray(X).ravel(), name="modified_features")

        preds = pd.Series(mf).map(self.medians_)
        preds = preds.fillna(self.global_median_).to_numpy(dtype=float)
        return preds

# 1. Train classifier
clf = ModifiedFeaturesMedianClassifier()
clf.fit(clean_data_train, clean_data_train["average_bill"])

# 2. Predict on test and train
test_preds = clf.predict(clean_data_test)
train_preds = clf.predict(clean_data_train)

# 3. Collect org_id + predictions into DataFrame
results = pd.DataFrame({
    "index_in_data": clean_data_test.index,
    "prediction": test_preds
})
results.to_csv("predictions.csv", index=False, header=False)

from sklearn.metrics import mean_squared_error

# Train and test predictions
rmse_train = np.sqrt(mean_squared_error(clean_data_train["average_bill"], train_preds))
rmse_test = np.sqrt(mean_squared_error(clean_data_test["average_bill"], test_preds))

print("Train RMSE:", rmse_train)
print("Test RMSE:", rmse_test)

# Balanced accuracy
bal_acc_train = balanced_accuracy_score(clean_data_train["average_bill"], train_preds)
bal_acc_test = balanced_accuracy_score(clean_data_test["average_bill"], test_preds)

print("Train Balanced Accuracy:", bal_acc_train)
print("Test Balanced Accuracy:", bal_acc_test)
# Out:
# Train RMSE: 32.4162067388783
# Test RMSE: 513.9898108867789
# Train Balanced Accuracy: 0.9931928777769354
# Test Balanced Accuracy: 0.2010249213051401
# /home/kishmakov/jupyter-env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:2801: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# /home/kishmakov/jupyter-env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:2801: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")

# %% [markdown]
# Модель, очевидно, очень сложная. Число параметров (различных категорий) в ней сопоставимо с числом объектов в обучающей выборке. А получилось ли хорошо?
#
# Давайте посчитаем RMSE и balanced_accuracy_score на обучающей и на тестовой выборках.
#
# **10. (1 балл) Введите их в Контест**

# %% [markdown]
# Налицо переобучение: на трейне метрики отличные, на тесте - вообще никакие
#
# В общем, не гонитесь за чрезмерной сложностью модели..

# %% [markdown]
# ## ML без данных что компутер без электричества

# %% [markdown]
# Возможно, вы смотрите на полученные выше результаты и думаете: вот если бы мы не какие-то убогие медианы предсказывали, а гоняли бы нейросети, то тут-то бы всё и получилось!
#
# Но, увы, совсем даже не всегда от счастья нас отделяет выбор хорошей модели (и стратегии обучения). Если данные не очень, то даже самая крутая модель не сработает. В этой ситуации нужно либо добывать новые фичи каким-то образом, либо собирать новые данные (увеличивать датасет), либо просто бросать задачу.
#
# Давайте посмотрим, что выжмет из наших данных одна из самых мощных моделей для табличных данных - градиентный бустинг на решающих деревьях в исполнении [CatBoost](https://catboost.ai/).

# %% [markdown]
# Но прежде, чем сделать fit, нам надо облагородить данные. Несмотря на то, что CatBoost отлично работает с категориальными фичами, мешок признаков из `rubrics_id` или `features_id` может ему оказаться не по зубам. Поэтому мы соберём датасет в пристойную матрицу, создав для каждого типа рубрик и фичей отдельный столбец и записав там единицы для тех объектов, у которых эта рубрика или фича имеет место.
#
# В матрице почти все элементы будут нулями. Такие матрицы считаются **разреженными** и их можно хранить гораздо эффективней, чем просто таблицей. Этим и займёмся)

# %% [markdown]
# Есть несколько форматов хранения разреженных матриц (многие из них реализованы в [пакете sparse библиотеки scipy](https://docs.scipy.org/doc/scipy/reference/sparse.html)), и каждый пригоден для чего-то своего.
#
# Создавать разреженную матрицу лучше в [формате COO](https://docs.scipy.org/doc/scipy/reference/generated/scipy.sparse.coo_array.html#scipy.sparse.coo_array). Он предполагает, что разреженная матрица задаётся в виде трёх списков: `row`, `col`, `data`, причём каждая тройка `(row[i], col[i], data[i])` кодирует элемент со значением `data[i]`, стоящий на позиции `(row[i], col[i])`. Считается, что на позициях `(row, col)`, которые ни разу не встретились, стоят нули.
#
# Нетрудно видеть, что заполнять такую матрицу - одно удовольствие, и особенно этому помогает тот факт, что **пара `(row, col)` может встретиться несколько раз** (тогда в итоговой матрице на соответствующей позиции стоит сумма соответствующих `data[i]`). Но, с другой стороны, почти ничего другого с такой матрицей не сделаешь: произвольного доступа к элементам она не предоставляет, умножить её тоже особо ничего не умножишь. Поэтому для дальнейшего использования созданную таким образом матрицу преобразуют в один из более удобных форматов, например, [CSR (compressed sparse row)](https://scipy-lectures.org/advanced/scipy_sparse/csr_matrix.html). Он, к примеру, хорошо подходит для умножения на вектор (потому что матрица хранится по строкам). Не будем разбирать его подробно, но можете почитать по ссылке, если интересно.

# %% [markdown]
# Вам нужно будет превратить обучающие и тестовые данные в разреженные матрицы `sparse_data_train` и `sparse_data_test` соответственно, таким образом, что:
#
# - столбец `city` превратится в столбец из единиц и нулей (например, 1 - Москва, 0 - Питер);
# - столбец `rating` перекочует в разреженные матрицы без изменений;
# - каждый типы рубрик и каждая фича превратятся в отдельный 0-1-принак;
#
# В тестовой выборке будут фичи, которых в обучающей выборке не было. С ними можно по-разному работать, но давайте создадим дополнительную фантомную фичу `feature_other`, в которой будет то, сколько неизвестных по обучающей выборке фичей есть у данного объекта.

# %%
from scipy.sparse import csr_matrix, hstack

def build_sparse(train_df, test_df):
    # --- 1. City encoding (binary msk=1, spb=0)
    city_train = (train_df['city'] == 'msk').astype(int).values.reshape(-1, 1)
    city_test = (test_df['city'] == 'msk').astype(int).values.reshape(-1, 1)

    # --- 2. Rating (keep numeric)
    rating_train = train_df[['rating']].values
    rating_test = test_df[['rating']].values

    # --- 3. Expand rubrics_id and features_id into sets
    train_rubrics = train_df['rubrics_id'].str.split()
    train_features = train_df['features_id'].str.split()
    test_rubrics = test_df['rubrics_id'].str.split()
    test_features = test_df['features_id'].str.split()

    # Collect unique IDs from training
    rubrics_vocab = sorted(set().union(*train_rubrics))
    features_vocab = sorted(set().union(*train_features))

    # Index maps
    rubric_to_idx = {r: i for i, r in enumerate(rubrics_vocab)}
    feature_to_idx = {f: i for i, f in enumerate(features_vocab)}

    # --- 4. Encode train rubrics/features
    rows, cols = [], []
    for i, rubs in enumerate(train_rubrics):
        for r in rubs:
            if r in rubric_to_idx:
                rows.append(i)
                cols.append(rubric_to_idx[r])
    rubrics_train = csr_matrix(( [1]*len(rows), (rows, cols) ), shape=(len(train_df), len(rubrics_vocab)))

    rows, cols = [], []
    for i, feats in enumerate(train_features):
        for f in feats:
            if f in feature_to_idx:
                rows.append(i)
                cols.append(feature_to_idx[f])
    features_train = csr_matrix(( [1]*len(rows), (rows, cols) ), shape=(len(train_df), len(features_vocab)))

    # --- 5. Encode test rubrics/features
    rows, cols = [], []
    for i, rubs in enumerate(test_rubrics):
        for r in rubs:
            if r in rubric_to_idx:  # known rubric
                rows.append(i)
                cols.append(rubric_to_idx[r])
    rubrics_test = csr_matrix(( [1]*len(rows), (rows, cols) ), shape=(len(test_df), len(rubrics_vocab)))

    rows, cols = [], []
    feature_other = [0]*len(test_df)
    for i, feats in enumerate(test_features):
        for f in feats:
            if f in feature_to_idx:  # known feature
                rows.append(i)
                cols.append(feature_to_idx[f])
            else:  # unseen feature → count in feature_other
                feature_other[i] += 1
    features_test = csr_matrix(( [1]*len(rows), (rows, cols) ), shape=(len(test_df), len(features_vocab)))
    feature_other = csr_matrix(pd.DataFrame(feature_other))

    # --- 6. Stack everything together
    sparse_data_train = hstack([
        csr_matrix(city_train),
        csr_matrix(rating_train),
        rubrics_train,
        features_train
    ])

    sparse_data_test = hstack([
        csr_matrix(city_test),
        csr_matrix(rating_test),
        rubrics_test,
        features_test,
        feature_other  # phantom column
    ])

    return sparse_data_train, sparse_data_test

clean_data_train, clean_data_test = train_test_split(
    filtered, stratify=filtered['average_bill'], test_size=0.33, random_state=42)    

sparse_data_train, sparse_data_test = build_sparse(clean_data_train, clean_data_test)

# %% [markdown]
# Данные готовы, и теперь можно запустить катбуст

# %%
from catboost import CatBoostClassifier

# %%
clf = CatBoostClassifier()
clf.fit(sparse_data_train, clean_data_train['average_bill'])

test_preds = clf.predict(sparse_data_test)
catb_acc_test = balanced_accuracy_score(clean_data_test["average_bill"], test_preds)

print("Test Balanced Accuracy:", catb_acc_test)
# Out:
# Learning rate set to 0.092536
# 0:	learn: 1.4347399	total: 15.8ms	remaining: 15.8s
# 1:	learn: 1.3126810	total: 29ms	remaining: 14.5s
# 2:	learn: 1.2190871	total: 41.8ms	remaining: 13.9s
# 3:	learn: 1.1475920	total: 54ms	remaining: 13.4s
# 4:	learn: 1.0884254	total: 65.4ms	remaining: 13s
# 5:	learn: 1.0403451	total: 77.4ms	remaining: 12.8s
# 6:	learn: 0.9990517	total: 88.1ms	remaining: 12.5s
# 7:	learn: 0.9649138	total: 98.8ms	remaining: 12.2s
# 8:	learn: 0.9351955	total: 110ms	remaining: 12.1s
# 9:	learn: 0.9095874	total: 121ms	remaining: 12s
# 10:	learn: 0.8879397	total: 132ms	remaining: 11.9s
# 11:	learn: 0.8696363	total: 143ms	remaining: 11.8s
# 12:	learn: 0.8523647	total: 153ms	remaining: 11.6s
# 13:	learn: 0.8359608	total: 164ms	remaining: 11.6s
# 14:	learn: 0.8191630	total: 175ms	remaining: 11.5s
# 15:	learn: 0.8041026	total: 186ms	remaining: 11.4s
# 16:	learn: 0.7931226	total: 197ms	remaining: 11.4s
# 17:	learn: 0.7822363	total: 209ms	remaining: 11.4s
# 18:	learn: 0.7737322	total: 221ms	remaining: 11.4s
# 19:	learn: 0.7662875	total: 230ms	remaining: 11.3s
# 20:	learn: 0.7585235	total: 242ms	remaining: 11.3s
# 21:	learn: 0.7521951	total: 253ms	remaining: 11.2s
# 22:	learn: 0.7447958	total: 264ms	remaining: 11.2s
# 23:	learn: 0.7387598	total: 276ms	remaining: 11.2s
# 24:	learn: 0.7344885	total: 287ms	remaining: 11.2s
# 25:	learn: 0.7303144	total: 298ms	remaining: 11.2s
# 26:	learn: 0.7236987	total: 309ms	remaining: 11.1s
# 27:	learn: 0.7204044	total: 320ms	remaining: 11.1s
# 28:	learn: 0.7166949	total: 330ms	remaining: 11.1s
# 29:	learn: 0.7117857	total: 341ms	remaining: 11s
# 30:	learn: 0.7074226	total: 353ms	remaining: 11s
# 31:	learn: 0.7045210	total: 363ms	remaining: 11s
# 32:	learn: 0.7015797	total: 374ms	remaining: 11s
# 33:	learn: 0.6988453	total: 384ms	remaining: 10.9s
# 34:	learn: 0.6955149	total: 395ms	remaining: 10.9s
# 35:	learn: 0.6918410	total: 406ms	remaining: 10.9s
# 36:	learn: 0.6898400	total: 418ms	remaining: 10.9s
# 37:	learn: 0.6882313	total: 428ms	remaining: 10.8s
# 38:	learn: 0.6865969	total: 439ms	remaining: 10.8s
# 39:	learn: 0.6842413	total: 451ms	remaining: 10.8s
# 40:	learn: 0.6825981	total: 462ms	remaining: 10.8s
# 41:	learn: 0.6810776	total: 472ms	remaining: 10.8s
# 42:	learn: 0.6801726	total: 483ms	remaining: 10.7s
# 43:	learn: 0.6795806	total: 493ms	remaining: 10.7s
# 44:	learn: 0.6783296	total: 503ms	remaining: 10.7s
# 45:	learn: 0.6766440	total: 514ms	remaining: 10.7s
# 46:	learn: 0.6748727	total: 525ms	remaining: 10.6s
# 47:	learn: 0.6737410	total: 536ms	remaining: 10.6s
# 48:	learn: 0.6722589	total: 547ms	remaining: 10.6s
# 49:	learn: 0.6716496	total: 558ms	remaining: 10.6s
# 50:	learn: 0.6703881	total: 568ms	remaining: 10.6s
# 51:	learn: 0.6682294	total: 580ms	remaining: 10.6s
# 52:	learn: 0.6661832	total: 591ms	remaining: 10.6s
# 53:	learn: 0.6655289	total: 602ms	remaining: 10.5s
# 54:	learn: 0.6639929	total: 613ms	remaining: 10.5s
# 55:	learn: 0.6629860	total: 624ms	remaining: 10.5s
# 56:	learn: 0.6627585	total: 632ms	remaining: 10.5s
# 57:	learn: 0.6618205	total: 645ms	remaining: 10.5s
# 58:	learn: 0.6616117	total: 656ms	remaining: 10.5s
# 59:	learn: 0.6597176	total: 667ms	remaining: 10.5s
# 60:	learn: 0.6595611	total: 677ms	remaining: 10.4s
# 61:	learn: 0.6591650	total: 688ms	remaining: 10.4s
# 62:	learn: 0.6586792	total: 698ms	remaining: 10.4s
# 63:	learn: 0.6579449	total: 709ms	remaining: 10.4s
# 64:	learn: 0.6571692	total: 720ms	remaining: 10.4s
# 65:	learn: 0.6559397	total: 731ms	remaining: 10.3s
# 66:	learn: 0.6557144	total: 742ms	remaining: 10.3s
# 67:	learn: 0.6546139	total: 753ms	remaining: 10.3s
# 68:	learn: 0.6536602	total: 763ms	remaining: 10.3s
# 69:	learn: 0.6535176	total: 774ms	remaining: 10.3s
# 70:	learn: 0.6526037	total: 785ms	remaining: 10.3s
# 71:	learn: 0.6519965	total: 797ms	remaining: 10.3s
# 72:	learn: 0.6512743	total: 809ms	remaining: 10.3s
# 73:	learn: 0.6502223	total: 819ms	remaining: 10.3s
# 74:	learn: 0.6495446	total: 831ms	remaining: 10.3s
# 75:	learn: 0.6484950	total: 843ms	remaining: 10.3s
# 76:	learn: 0.6482026	total: 854ms	remaining: 10.2s
# 77:	learn: 0.6476486	total: 866ms	remaining: 10.2s
# 78:	learn: 0.6474400	total: 878ms	remaining: 10.2s
# 79:	learn: 0.6473169	total: 889ms	remaining: 10.2s
# 80:	learn: 0.6469035	total: 900ms	remaining: 10.2s
# 81:	learn: 0.6467318	total: 911ms	remaining: 10.2s
# 82:	learn: 0.6461395	total: 923ms	remaining: 10.2s
# 83:	learn: 0.6446840	total: 936ms	remaining: 10.2s
# 84:	learn: 0.6441994	total: 948ms	remaining: 10.2s
# 85:	learn: 0.6436522	total: 961ms	remaining: 10.2s
# 86:	learn: 0.6435219	total: 972ms	remaining: 10.2s
# 87:	learn: 0.6424449	total: 985ms	remaining: 10.2s
# 88:	learn: 0.6418946	total: 1s	remaining: 10.2s
# 89:	learn: 0.6417772	total: 1.01s	remaining: 10.2s
# 90:	learn: 0.6411961	total: 1.02s	remaining: 10.2s
# 91:	learn: 0.6409613	total: 1.04s	remaining: 10.3s
# 92:	learn: 0.6400255	total: 1.07s	remaining: 10.4s
# 93:	learn: 0.6392555	total: 1.08s	remaining: 10.5s
# 94:	learn: 0.6391117	total: 1.1s	remaining: 10.4s
# 95:	learn: 0.6387355	total: 1.11s	remaining: 10.4s
# 96:	learn: 0.6385166	total: 1.12s	remaining: 10.4s
# 97:	learn: 0.6383627	total: 1.14s	remaining: 10.5s
# 98:	learn: 0.6378277	total: 1.15s	remaining: 10.4s
# 99:	learn: 0.6374252	total: 1.16s	remaining: 10.4s
# 100:	learn: 0.6373571	total: 1.17s	remaining: 10.4s
# 101:	learn: 0.6368726	total: 1.18s	remaining: 10.4s
# 102:	learn: 0.6368066	total: 1.19s	remaining: 10.3s
# 103:	learn: 0.6366856	total: 1.2s	remaining: 10.3s
# 104:	learn: 0.6358967	total: 1.21s	remaining: 10.3s
# 105:	learn: 0.6352782	total: 1.22s	remaining: 10.3s
# 106:	learn: 0.6348168	total: 1.23s	remaining: 10.3s
# 107:	learn: 0.6337177	total: 1.25s	remaining: 10.3s
# 108:	learn: 0.6332828	total: 1.26s	remaining: 10.3s
# 109:	learn: 0.6331798	total: 1.27s	remaining: 10.3s
# 110:	learn: 0.6331150	total: 1.28s	remaining: 10.2s
# 111:	learn: 0.6327397	total: 1.29s	remaining: 10.2s
# 112:	learn: 0.6323037	total: 1.3s	remaining: 10.2s
# 113:	learn: 0.6316338	total: 1.31s	remaining: 10.2s
# 114:	learn: 0.6313170	total: 1.33s	remaining: 10.2s
# 115:	learn: 0.6307858	total: 1.34s	remaining: 10.2s
# 116:	learn: 0.6305014	total: 1.35s	remaining: 10.2s
# 117:	learn: 0.6303903	total: 1.36s	remaining: 10.2s
# 118:	learn: 0.6296850	total: 1.37s	remaining: 10.2s
# 119:	learn: 0.6290958	total: 1.39s	remaining: 10.2s
# 120:	learn: 0.6286488	total: 1.4s	remaining: 10.2s
# 121:	learn: 0.6282006	total: 1.41s	remaining: 10.1s
# 122:	learn: 0.6279510	total: 1.42s	remaining: 10.1s
# 123:	learn: 0.6270634	total: 1.43s	remaining: 10.1s
# 124:	learn: 0.6260343	total: 1.45s	remaining: 10.1s
# 125:	learn: 0.6257203	total: 1.46s	remaining: 10.1s
# 126:	learn: 0.6254891	total: 1.47s	remaining: 10.1s
# 127:	learn: 0.6247236	total: 1.48s	remaining: 10.1s
# 128:	learn: 0.6245828	total: 1.49s	remaining: 10.1s
# 129:	learn: 0.6242968	total: 1.5s	remaining: 10.1s
# 130:	learn: 0.6237364	total: 1.51s	remaining: 10s
# 131:	learn: 0.6229854	total: 1.52s	remaining: 10s
# 132:	learn: 0.6228066	total: 1.53s	remaining: 10s
# 133:	learn: 0.6220620	total: 1.54s	remaining: 9.98s
# 134:	learn: 0.6218493	total: 1.55s	remaining: 9.97s
# 135:	learn: 0.6215035	total: 1.57s	remaining: 9.95s
# 136:	learn: 0.6213291	total: 1.57s	remaining: 9.93s
# 137:	learn: 0.6208070	total: 1.59s	remaining: 9.91s
# 138:	learn: 0.6205657	total: 1.6s	remaining: 9.9s
# 139:	learn: 0.6204241	total: 1.61s	remaining: 9.88s
# 140:	learn: 0.6203435	total: 1.62s	remaining: 9.86s
# 141:	learn: 0.6201589	total: 1.63s	remaining: 9.85s
# 142:	learn: 0.6199199	total: 1.64s	remaining: 9.83s
# 143:	learn: 0.6196924	total: 1.65s	remaining: 9.82s
# 144:	learn: 0.6194664	total: 1.66s	remaining: 9.8s
# 145:	learn: 0.6193902	total: 1.67s	remaining: 9.79s
# 146:	learn: 0.6188877	total: 1.68s	remaining: 9.78s
# 147:	learn: 0.6187683	total: 1.7s	remaining: 9.76s
# 148:	learn: 0.6182704	total: 1.71s	remaining: 9.75s
# 149:	learn: 0.6178204	total: 1.72s	remaining: 9.74s
# 150:	learn: 0.6172161	total: 1.73s	remaining: 9.73s
# 151:	learn: 0.6169616	total: 1.74s	remaining: 9.71s
# 152:	learn: 0.6167104	total: 1.75s	remaining: 9.7s
# 153:	learn: 0.6165576	total: 1.76s	remaining: 9.69s
# 154:	learn: 0.6163547	total: 1.77s	remaining: 9.67s
# 155:	learn: 0.6159034	total: 1.78s	remaining: 9.66s
# 156:	learn: 0.6156414	total: 1.8s	remaining: 9.66s
# 157:	learn: 0.6152942	total: 1.81s	remaining: 9.65s
# 158:	learn: 0.6147039	total: 1.82s	remaining: 9.64s
# 159:	learn: 0.6144118	total: 1.83s	remaining: 9.62s
# 160:	learn: 0.6142879	total: 1.84s	remaining: 9.61s
# 161:	learn: 0.6139034	total: 1.85s	remaining: 9.6s
# 162:	learn: 0.6137685	total: 1.87s	remaining: 9.58s
# 163:	learn: 0.6127430	total: 1.88s	remaining: 9.57s
# 164:	learn: 0.6125841	total: 1.89s	remaining: 9.55s
# 165:	learn: 0.6122817	total: 1.9s	remaining: 9.54s
# 166:	learn: 0.6120395	total: 1.91s	remaining: 9.52s
# 167:	learn: 0.6119416	total: 1.92s	remaining: 9.5s
# 168:	learn: 0.6117905	total: 1.93s	remaining: 9.48s
# 169:	learn: 0.6115427	total: 1.94s	remaining: 9.47s
# 170:	learn: 0.6113843	total: 1.95s	remaining: 9.46s
# 171:	learn: 0.6112812	total: 1.96s	remaining: 9.44s
# 172:	learn: 0.6109193	total: 1.97s	remaining: 9.43s
# 173:	learn: 0.6107717	total: 1.98s	remaining: 9.41s
# 174:	learn: 0.6106153	total: 1.99s	remaining: 9.4s
# 175:	learn: 0.6104762	total: 2s	remaining: 9.38s
# 176:	learn: 0.6103105	total: 2.02s	remaining: 9.37s
# 177:	learn: 0.6101392	total: 2.03s	remaining: 9.36s
# 178:	learn: 0.6100493	total: 2.04s	remaining: 9.34s
# 179:	learn: 0.6098917	total: 2.05s	remaining: 9.33s
# 180:	learn: 0.6097580	total: 2.06s	remaining: 9.32s
# 181:	learn: 0.6093769	total: 2.07s	remaining: 9.31s
# 182:	learn: 0.6090902	total: 2.08s	remaining: 9.29s
# 183:	learn: 0.6087719	total: 2.09s	remaining: 9.28s
# 184:	learn: 0.6084854	total: 2.1s	remaining: 9.27s
# 185:	learn: 0.6083852	total: 2.11s	remaining: 9.25s
# 186:	learn: 0.6082921	total: 2.12s	remaining: 9.23s
# 187:	learn: 0.6079944	total: 2.13s	remaining: 9.22s
# 188:	learn: 0.6075865	total: 2.15s	remaining: 9.21s
# 189:	learn: 0.6073353	total: 2.16s	remaining: 9.2s
# 190:	learn: 0.6071316	total: 2.17s	remaining: 9.19s
# 191:	learn: 0.6068635	total: 2.18s	remaining: 9.18s
# 192:	learn: 0.6066619	total: 2.19s	remaining: 9.16s
# 193:	learn: 0.6061560	total: 2.2s	remaining: 9.15s
# 194:	learn: 0.6058930	total: 2.21s	remaining: 9.14s
# 195:	learn: 0.6056178	total: 2.22s	remaining: 9.13s
# 196:	learn: 0.6055058	total: 2.23s	remaining: 9.11s
# 197:	learn: 0.6054626	total: 2.25s	remaining: 9.1s
# 198:	learn: 0.6054206	total: 2.25s	remaining: 9.08s
# 199:	learn: 0.6051521	total: 2.27s	remaining: 9.08s
# 200:	learn: 0.6049915	total: 2.28s	remaining: 9.07s
# 201:	learn: 0.6045128	total: 2.29s	remaining: 9.06s
# 202:	learn: 0.6039671	total: 2.3s	remaining: 9.05s
# 203:	learn: 0.6038671	total: 2.31s	remaining: 9.03s
# 204:	learn: 0.6035351	total: 2.33s	remaining: 9.02s
# 205:	learn: 0.6033660	total: 2.33s	remaining: 9s
# 206:	learn: 0.6031291	total: 2.35s	remaining: 8.99s
# 207:	learn: 0.6030035	total: 2.36s	remaining: 8.97s
# 208:	learn: 0.6028584	total: 2.37s	remaining: 8.96s
# 209:	learn: 0.6026483	total: 2.38s	remaining: 8.95s
# 210:	learn: 0.6024585	total: 2.39s	remaining: 8.94s
# 211:	learn: 0.6023830	total: 2.4s	remaining: 8.92s
# 212:	learn: 0.6021653	total: 2.41s	remaining: 8.91s
# 213:	learn: 0.6019843	total: 2.42s	remaining: 8.89s
# 214:	learn: 0.6016923	total: 2.43s	remaining: 8.88s
# 215:	learn: 0.6012282	total: 2.44s	remaining: 8.87s
# 216:	learn: 0.6011250	total: 2.45s	remaining: 8.86s
# 217:	learn: 0.6010897	total: 2.46s	remaining: 8.84s
# 218:	learn: 0.6009200	total: 2.48s	remaining: 8.84s
# 219:	learn: 0.6003786	total: 2.49s	remaining: 8.82s
# 220:	learn: 0.6001834	total: 2.5s	remaining: 8.81s
# 221:	learn: 0.6001138	total: 2.51s	remaining: 8.8s
# 222:	learn: 0.5999800	total: 2.52s	remaining: 8.79s
# 223:	learn: 0.5997355	total: 2.53s	remaining: 8.77s
# 224:	learn: 0.5994289	total: 2.54s	remaining: 8.76s
# 225:	learn: 0.5992538	total: 2.55s	remaining: 8.74s
# 226:	learn: 0.5991501	total: 2.56s	remaining: 8.73s
# 227:	learn: 0.5989574	total: 2.57s	remaining: 8.72s
# 228:	learn: 0.5989285	total: 2.58s	remaining: 8.7s
# 229:	learn: 0.5987515	total: 2.6s	remaining: 8.69s
# 230:	learn: 0.5986092	total: 2.61s	remaining: 8.68s
# 231:	learn: 0.5983007	total: 2.62s	remaining: 8.67s
# 232:	learn: 0.5981852	total: 2.63s	remaining: 8.65s
# 233:	learn: 0.5978282	total: 2.64s	remaining: 8.64s
# 234:	learn: 0.5976668	total: 2.65s	remaining: 8.63s
# 235:	learn: 0.5975731	total: 2.66s	remaining: 8.62s
# 236:	learn: 0.5974748	total: 2.67s	remaining: 8.61s
# 237:	learn: 0.5972993	total: 2.69s	remaining: 8.6s
# 238:	learn: 0.5970612	total: 2.69s	remaining: 8.58s
# 239:	learn: 0.5965074	total: 2.71s	remaining: 8.57s
# 240:	learn: 0.5963822	total: 2.72s	remaining: 8.56s
# 241:	learn: 0.5963500	total: 2.73s	remaining: 8.54s
# 242:	learn: 0.5962817	total: 2.74s	remaining: 8.53s
# 243:	learn: 0.5960766	total: 2.75s	remaining: 8.52s
# 244:	learn: 0.5958069	total: 2.76s	remaining: 8.51s
# 245:	learn: 0.5955328	total: 2.77s	remaining: 8.49s
# 246:	learn: 0.5953891	total: 2.78s	remaining: 8.48s
# 247:	learn: 0.5952133	total: 2.79s	remaining: 8.47s
# 248:	learn: 0.5951498	total: 2.8s	remaining: 8.46s
# 249:	learn: 0.5951276	total: 2.81s	remaining: 8.44s
# 250:	learn: 0.5949742	total: 2.82s	remaining: 8.43s
# 251:	learn: 0.5949111	total: 2.83s	remaining: 8.41s
# 252:	learn: 0.5946355	total: 2.85s	remaining: 8.4s
# 253:	learn: 0.5944897	total: 2.86s	remaining: 8.39s
# 254:	learn: 0.5943882	total: 2.87s	remaining: 8.38s
# 255:	learn: 0.5941675	total: 2.88s	remaining: 8.37s
# 256:	learn: 0.5939570	total: 2.89s	remaining: 8.36s
# 257:	learn: 0.5939007	total: 2.9s	remaining: 8.35s
# 258:	learn: 0.5937887	total: 2.91s	remaining: 8.34s
# 259:	learn: 0.5937415	total: 2.92s	remaining: 8.32s
# 260:	learn: 0.5936534	total: 2.94s	remaining: 8.31s
# 261:	learn: 0.5935060	total: 2.94s	remaining: 8.3s
# 262:	learn: 0.5931837	total: 2.96s	remaining: 8.29s
# 263:	learn: 0.5931457	total: 2.97s	remaining: 8.28s
# 264:	learn: 0.5931332	total: 2.98s	remaining: 8.26s
# 265:	learn: 0.5930872	total: 2.99s	remaining: 8.25s
# 266:	learn: 0.5930164	total: 3s	remaining: 8.23s
# 267:	learn: 0.5929955	total: 3.01s	remaining: 8.22s
# 268:	learn: 0.5928248	total: 3.02s	remaining: 8.21s
# 269:	learn: 0.5924818	total: 3.03s	remaining: 8.2s
# 270:	learn: 0.5921205	total: 3.04s	remaining: 8.19s
# 271:	learn: 0.5920139	total: 3.05s	remaining: 8.18s
# 272:	learn: 0.5917769	total: 3.06s	remaining: 8.16s
# 273:	learn: 0.5916998	total: 3.08s	remaining: 8.15s
# 274:	learn: 0.5914371	total: 3.09s	remaining: 8.14s
# 275:	learn: 0.5913861	total: 3.1s	remaining: 8.13s
# 276:	learn: 0.5913497	total: 3.11s	remaining: 8.12s
# 277:	learn: 0.5912492	total: 3.12s	remaining: 8.11s
# 278:	learn: 0.5909709	total: 3.13s	remaining: 8.1s
# 279:	learn: 0.5908691	total: 3.14s	remaining: 8.09s
# 280:	learn: 0.5906262	total: 3.15s	remaining: 8.07s
# 281:	learn: 0.5905790	total: 3.17s	remaining: 8.06s
# 282:	learn: 0.5903867	total: 3.18s	remaining: 8.05s
# 283:	learn: 0.5902784	total: 3.19s	remaining: 8.04s
# 284:	learn: 0.5901839	total: 3.2s	remaining: 8.03s
# 285:	learn: 0.5899649	total: 3.21s	remaining: 8.02s
# 286:	learn: 0.5899457	total: 3.22s	remaining: 8.01s
# 287:	learn: 0.5896329	total: 3.23s	remaining: 8s
# 288:	learn: 0.5894410	total: 3.25s	remaining: 7.98s
# 289:	learn: 0.5892589	total: 3.26s	remaining: 7.97s
# 290:	learn: 0.5887963	total: 3.27s	remaining: 7.97s
# 291:	learn: 0.5887411	total: 3.28s	remaining: 7.96s
# 292:	learn: 0.5886591	total: 3.29s	remaining: 7.95s
# 293:	learn: 0.5884304	total: 3.3s	remaining: 7.93s
# 294:	learn: 0.5884049	total: 3.31s	remaining: 7.92s
# 295:	learn: 0.5882652	total: 3.33s	remaining: 7.91s
# 296:	learn: 0.5879137	total: 3.34s	remaining: 7.9s
# 297:	learn: 0.5877126	total: 3.35s	remaining: 7.89s
# 298:	learn: 0.5873033	total: 3.36s	remaining: 7.88s
# 299:	learn: 0.5872028	total: 3.37s	remaining: 7.87s
# 300:	learn: 0.5868722	total: 3.38s	remaining: 7.86s
# 301:	learn: 0.5865762	total: 3.39s	remaining: 7.84s
# 302:	learn: 0.5865363	total: 3.4s	remaining: 7.83s
# 303:	learn: 0.5863646	total: 3.42s	remaining: 7.82s
# 304:	learn: 0.5859304	total: 3.43s	remaining: 7.81s
# 305:	learn: 0.5858798	total: 3.44s	remaining: 7.8s
# 306:	learn: 0.5858417	total: 3.45s	remaining: 7.78s
# 307:	learn: 0.5856936	total: 3.46s	remaining: 7.77s
# 308:	learn: 0.5856349	total: 3.47s	remaining: 7.76s
# 309:	learn: 0.5854625	total: 3.48s	remaining: 7.75s
# 310:	learn: 0.5853278	total: 3.49s	remaining: 7.73s
# 311:	learn: 0.5851529	total: 3.5s	remaining: 7.72s
# 312:	learn: 0.5848379	total: 3.51s	remaining: 7.71s
# 313:	learn: 0.5847301	total: 3.52s	remaining: 7.7s
# 314:	learn: 0.5845393	total: 3.54s	remaining: 7.69s
# 315:	learn: 0.5844276	total: 3.55s	remaining: 7.68s
# 316:	learn: 0.5843934	total: 3.56s	remaining: 7.67s
# 317:	learn: 0.5842057	total: 3.57s	remaining: 7.66s
# 318:	learn: 0.5840455	total: 3.58s	remaining: 7.64s
# 319:	learn: 0.5840247	total: 3.59s	remaining: 7.63s
# 320:	learn: 0.5839753	total: 3.6s	remaining: 7.61s
# 321:	learn: 0.5838952	total: 3.61s	remaining: 7.6s
# 322:	learn: 0.5836414	total: 3.62s	remaining: 7.59s
# 323:	learn: 0.5834394	total: 3.63s	remaining: 7.58s
# 324:	learn: 0.5833901	total: 3.64s	remaining: 7.57s
# 325:	learn: 0.5833384	total: 3.65s	remaining: 7.55s
# 326:	learn: 0.5831430	total: 3.66s	remaining: 7.54s
# 327:	learn: 0.5830426	total: 3.67s	remaining: 7.53s
# 328:	learn: 0.5826025	total: 3.69s	remaining: 7.52s
# 329:	learn: 0.5825702	total: 3.7s	remaining: 7.51s
# 330:	learn: 0.5822995	total: 3.71s	remaining: 7.5s
# 331:	learn: 0.5822497	total: 3.72s	remaining: 7.49s
# 332:	learn: 0.5820583	total: 3.73s	remaining: 7.48s
# 333:	learn: 0.5816111	total: 3.74s	remaining: 7.47s
# 334:	learn: 0.5813164	total: 3.76s	remaining: 7.46s
# 335:	learn: 0.5812827	total: 3.77s	remaining: 7.44s
# 336:	learn: 0.5811291	total: 3.78s	remaining: 7.43s
# 337:	learn: 0.5810397	total: 3.79s	remaining: 7.42s
# 338:	learn: 0.5810271	total: 3.8s	remaining: 7.41s
# 339:	learn: 0.5810094	total: 3.81s	remaining: 7.39s
# 340:	learn: 0.5809772	total: 3.82s	remaining: 7.38s
# 341:	learn: 0.5809059	total: 3.83s	remaining: 7.37s
# 342:	learn: 0.5805810	total: 3.84s	remaining: 7.36s
# 343:	learn: 0.5805402	total: 3.85s	remaining: 7.34s
# 344:	learn: 0.5803780	total: 3.86s	remaining: 7.33s
# 345:	learn: 0.5803120	total: 3.87s	remaining: 7.32s
# 346:	learn: 0.5802244	total: 3.88s	remaining: 7.31s
# 347:	learn: 0.5801655	total: 3.89s	remaining: 7.29s
# 348:	learn: 0.5800674	total: 3.91s	remaining: 7.29s
# 349:	learn: 0.5798062	total: 3.92s	remaining: 7.28s
# 350:	learn: 0.5797264	total: 3.93s	remaining: 7.27s
# 351:	learn: 0.5796352	total: 3.94s	remaining: 7.26s
# 352:	learn: 0.5793025	total: 3.95s	remaining: 7.25s
# 353:	learn: 0.5789519	total: 3.96s	remaining: 7.24s
# 354:	learn: 0.5789123	total: 3.98s	remaining: 7.22s
# 355:	learn: 0.5788947	total: 3.98s	remaining: 7.21s
# 356:	learn: 0.5787004	total: 4s	remaining: 7.2s
# 357:	learn: 0.5786895	total: 4.01s	remaining: 7.18s
# 358:	learn: 0.5785559	total: 4.02s	remaining: 7.17s
# 359:	learn: 0.5784785	total: 4.03s	remaining: 7.16s
# 360:	learn: 0.5783337	total: 4.04s	remaining: 7.15s
# 361:	learn: 0.5783169	total: 4.05s	remaining: 7.14s
# 362:	learn: 0.5781249	total: 4.06s	remaining: 7.13s
# 363:	learn: 0.5780694	total: 4.07s	remaining: 7.11s
# 364:	learn: 0.5780289	total: 4.08s	remaining: 7.1s
# 365:	learn: 0.5775808	total: 4.09s	remaining: 7.09s
# 366:	learn: 0.5774694	total: 4.11s	remaining: 7.08s
# 367:	learn: 0.5773536	total: 4.12s	remaining: 7.07s
# 368:	learn: 0.5771062	total: 4.13s	remaining: 7.06s
# 369:	learn: 0.5770844	total: 4.14s	remaining: 7.05s
# 370:	learn: 0.5770181	total: 4.15s	remaining: 7.03s
# 371:	learn: 0.5769781	total: 4.16s	remaining: 7.02s
# 372:	learn: 0.5767548	total: 4.17s	remaining: 7.01s
# 373:	learn: 0.5765926	total: 4.18s	remaining: 7s
# 374:	learn: 0.5762576	total: 4.19s	remaining: 6.99s
# 375:	learn: 0.5761826	total: 4.2s	remaining: 6.98s
# 376:	learn: 0.5760949	total: 4.21s	remaining: 6.96s
# 377:	learn: 0.5759829	total: 4.22s	remaining: 6.95s
# 378:	learn: 0.5759736	total: 4.24s	remaining: 6.94s
# 379:	learn: 0.5757628	total: 4.25s	remaining: 6.93s
# 380:	learn: 0.5756021	total: 4.26s	remaining: 6.92s
# 381:	learn: 0.5752513	total: 4.27s	remaining: 6.91s
# 382:	learn: 0.5749217	total: 4.28s	remaining: 6.9s
# 383:	learn: 0.5748731	total: 4.29s	remaining: 6.88s
# 384:	learn: 0.5748181	total: 4.3s	remaining: 6.87s
# 385:	learn: 0.5746599	total: 4.31s	remaining: 6.86s
# 386:	learn: 0.5746000	total: 4.32s	remaining: 6.85s
# 387:	learn: 0.5745196	total: 4.33s	remaining: 6.84s
# 388:	learn: 0.5744194	total: 4.35s	remaining: 6.83s
# 389:	learn: 0.5741666	total: 4.36s	remaining: 6.82s
# 390:	learn: 0.5739737	total: 4.37s	remaining: 6.8s
# 391:	learn: 0.5739087	total: 4.38s	remaining: 6.79s
# 392:	learn: 0.5738153	total: 4.39s	remaining: 6.78s
# 393:	learn: 0.5735597	total: 4.4s	remaining: 6.77s
# 394:	learn: 0.5735184	total: 4.41s	remaining: 6.76s
# 395:	learn: 0.5735070	total: 4.42s	remaining: 6.75s
# 396:	learn: 0.5733506	total: 4.43s	remaining: 6.73s
# 397:	learn: 0.5731863	total: 4.44s	remaining: 6.72s
# 398:	learn: 0.5731296	total: 4.46s	remaining: 6.71s
# 399:	learn: 0.5730203	total: 4.47s	remaining: 6.7s
# 400:	learn: 0.5729052	total: 4.48s	remaining: 6.69s
# 401:	learn: 0.5728470	total: 4.49s	remaining: 6.67s
# 402:	learn: 0.5724198	total: 4.5s	remaining: 6.66s
# 403:	learn: 0.5721507	total: 4.51s	remaining: 6.65s
# 404:	learn: 0.5720765	total: 4.52s	remaining: 6.64s
# 405:	learn: 0.5720613	total: 4.53s	remaining: 6.63s
# 406:	learn: 0.5719734	total: 4.54s	remaining: 6.62s
# 407:	learn: 0.5719419	total: 4.55s	remaining: 6.6s
# 408:	learn: 0.5718459	total: 4.56s	remaining: 6.59s
# 409:	learn: 0.5717990	total: 4.57s	remaining: 6.58s
# 410:	learn: 0.5714988	total: 4.58s	remaining: 6.57s
# 411:	learn: 0.5713566	total: 4.59s	remaining: 6.56s
# 412:	learn: 0.5711426	total: 4.61s	remaining: 6.54s
# 413:	learn: 0.5710470	total: 4.62s	remaining: 6.53s
# 414:	learn: 0.5708281	total: 4.63s	remaining: 6.52s
# 415:	learn: 0.5707900	total: 4.64s	remaining: 6.51s
# 416:	learn: 0.5707232	total: 4.65s	remaining: 6.5s
# 417:	learn: 0.5706692	total: 4.66s	remaining: 6.49s
# 418:	learn: 0.5703066	total: 4.67s	remaining: 6.47s
# 419:	learn: 0.5702678	total: 4.68s	remaining: 6.46s
# 420:	learn: 0.5700018	total: 4.69s	remaining: 6.45s
# 421:	learn: 0.5699672	total: 4.7s	remaining: 6.44s
# 422:	learn: 0.5699517	total: 4.71s	remaining: 6.43s
# 423:	learn: 0.5698594	total: 4.72s	remaining: 6.42s
# 424:	learn: 0.5697423	total: 4.74s	remaining: 6.41s
# 425:	learn: 0.5695647	total: 4.75s	remaining: 6.4s
# 426:	learn: 0.5695302	total: 4.76s	remaining: 6.39s
# 427:	learn: 0.5695035	total: 4.77s	remaining: 6.38s
# 428:	learn: 0.5693755	total: 4.78s	remaining: 6.36s
# 429:	learn: 0.5691818	total: 4.79s	remaining: 6.35s
# 430:	learn: 0.5690917	total: 4.8s	remaining: 6.34s
# 431:	learn: 0.5688706	total: 4.81s	remaining: 6.33s
# 432:	learn: 0.5687940	total: 4.82s	remaining: 6.32s
# 433:	learn: 0.5686096	total: 4.83s	remaining: 6.3s
# 434:	learn: 0.5685272	total: 4.84s	remaining: 6.29s
# 435:	learn: 0.5684968	total: 4.86s	remaining: 6.28s
# 436:	learn: 0.5680462	total: 4.87s	remaining: 6.27s
# 437:	learn: 0.5678622	total: 4.88s	remaining: 6.26s
# 438:	learn: 0.5678019	total: 4.89s	remaining: 6.25s
# 439:	learn: 0.5675279	total: 4.91s	remaining: 6.24s
# 440:	learn: 0.5673300	total: 4.92s	remaining: 6.23s
# 441:	learn: 0.5672731	total: 4.93s	remaining: 6.22s
# 442:	learn: 0.5671368	total: 4.94s	remaining: 6.21s
# 443:	learn: 0.5670055	total: 4.95s	remaining: 6.2s
# 444:	learn: 0.5668859	total: 4.96s	remaining: 6.19s
# 445:	learn: 0.5666288	total: 4.97s	remaining: 6.18s
# 446:	learn: 0.5666019	total: 4.98s	remaining: 6.17s
# 447:	learn: 0.5665600	total: 4.99s	remaining: 6.15s
# 448:	learn: 0.5663889	total: 5s	remaining: 6.14s
# 449:	learn: 0.5662804	total: 5.02s	remaining: 6.13s
# 450:	learn: 0.5660763	total: 5.03s	remaining: 6.12s
# 451:	learn: 0.5658339	total: 5.04s	remaining: 6.11s
# 452:	learn: 0.5657739	total: 5.05s	remaining: 6.1s
# 453:	learn: 0.5657151	total: 5.06s	remaining: 6.09s
# 454:	learn: 0.5656218	total: 5.08s	remaining: 6.08s
# 455:	learn: 0.5655617	total: 5.09s	remaining: 6.07s
# 456:	learn: 0.5654483	total: 5.1s	remaining: 6.06s
# 457:	learn: 0.5654065	total: 5.11s	remaining: 6.04s
# 458:	learn: 0.5653961	total: 5.12s	remaining: 6.03s
# 459:	learn: 0.5653689	total: 5.13s	remaining: 6.02s
# 460:	learn: 0.5652402	total: 5.14s	remaining: 6.01s
# 461:	learn: 0.5651673	total: 5.16s	remaining: 6s
# 462:	learn: 0.5650384	total: 5.17s	remaining: 5.99s
# 463:	learn: 0.5649660	total: 5.18s	remaining: 5.98s
# 464:	learn: 0.5649434	total: 5.19s	remaining: 5.97s
# 465:	learn: 0.5649208	total: 5.2s	remaining: 5.96s
# 466:	learn: 0.5646038	total: 5.21s	remaining: 5.95s
# 467:	learn: 0.5645126	total: 5.22s	remaining: 5.94s
# 468:	learn: 0.5644352	total: 5.23s	remaining: 5.92s
# 469:	learn: 0.5643790	total: 5.24s	remaining: 5.91s
# 470:	learn: 0.5643617	total: 5.25s	remaining: 5.9s
# 471:	learn: 0.5642914	total: 5.27s	remaining: 5.89s
# 472:	learn: 0.5642808	total: 5.28s	remaining: 5.88s
# 473:	learn: 0.5641995	total: 5.29s	remaining: 5.87s
# 474:	learn: 0.5640504	total: 5.3s	remaining: 5.86s
# 475:	learn: 0.5639596	total: 5.31s	remaining: 5.85s
# 476:	learn: 0.5636657	total: 5.32s	remaining: 5.84s
# 477:	learn: 0.5634900	total: 5.33s	remaining: 5.82s
# 478:	learn: 0.5634667	total: 5.35s	remaining: 5.81s
# 479:	learn: 0.5633225	total: 5.36s	remaining: 5.8s
# 480:	learn: 0.5632642	total: 5.37s	remaining: 5.79s
# 481:	learn: 0.5631357	total: 5.38s	remaining: 5.78s
# 482:	learn: 0.5630757	total: 5.39s	remaining: 5.77s
# 483:	learn: 0.5627400	total: 5.4s	remaining: 5.76s
# 484:	learn: 0.5626704	total: 5.41s	remaining: 5.75s
# 485:	learn: 0.5626234	total: 5.42s	remaining: 5.74s
# 486:	learn: 0.5626151	total: 5.43s	remaining: 5.72s
# 487:	learn: 0.5625375	total: 5.45s	remaining: 5.71s
# 488:	learn: 0.5624514	total: 5.46s	remaining: 5.7s
# 489:	learn: 0.5624057	total: 5.47s	remaining: 5.69s
# 490:	learn: 0.5623245	total: 5.48s	remaining: 5.68s
# 491:	learn: 0.5621562	total: 5.49s	remaining: 5.67s
# 492:	learn: 0.5620542	total: 5.5s	remaining: 5.66s
# 493:	learn: 0.5620027	total: 5.51s	remaining: 5.64s
# 494:	learn: 0.5618853	total: 5.52s	remaining: 5.63s
# 495:	learn: 0.5618003	total: 5.53s	remaining: 5.62s
# 496:	learn: 0.5616668	total: 5.54s	remaining: 5.61s
# 497:	learn: 0.5616364	total: 5.55s	remaining: 5.6s
# 498:	learn: 0.5616291	total: 5.57s	remaining: 5.59s
# 499:	learn: 0.5615706	total: 5.58s	remaining: 5.58s
# 500:	learn: 0.5615073	total: 5.59s	remaining: 5.57s
# 501:	learn: 0.5615010	total: 5.6s	remaining: 5.55s
# 502:	learn: 0.5614085	total: 5.61s	remaining: 5.54s
# 503:	learn: 0.5613869	total: 5.62s	remaining: 5.53s
# 504:	learn: 0.5613371	total: 5.63s	remaining: 5.52s
# 505:	learn: 0.5612408	total: 5.64s	remaining: 5.51s
# 506:	learn: 0.5610928	total: 5.65s	remaining: 5.5s
# 507:	learn: 0.5608691	total: 5.67s	remaining: 5.49s
# 508:	learn: 0.5608366	total: 5.68s	remaining: 5.47s
# 509:	learn: 0.5608140	total: 5.69s	remaining: 5.46s
# 510:	learn: 0.5607739	total: 5.7s	remaining: 5.45s
# 511:	learn: 0.5607294	total: 5.71s	remaining: 5.44s
# 512:	learn: 0.5606373	total: 5.72s	remaining: 5.43s
# 513:	learn: 0.5603010	total: 5.73s	remaining: 5.42s
# 514:	learn: 0.5600822	total: 5.74s	remaining: 5.41s
# 515:	learn: 0.5599600	total: 5.75s	remaining: 5.4s
# 516:	learn: 0.5599028	total: 5.76s	remaining: 5.38s
# 517:	learn: 0.5598838	total: 5.77s	remaining: 5.37s
# 518:	learn: 0.5598684	total: 5.79s	remaining: 5.36s
# 519:	learn: 0.5597690	total: 5.79s	remaining: 5.35s
# 520:	learn: 0.5596598	total: 5.81s	remaining: 5.34s
# 521:	learn: 0.5596083	total: 5.82s	remaining: 5.33s
# 522:	learn: 0.5592583	total: 5.83s	remaining: 5.32s
# 523:	learn: 0.5592512	total: 5.84s	remaining: 5.3s
# 524:	learn: 0.5591359	total: 5.85s	remaining: 5.29s
# 525:	learn: 0.5591268	total: 5.86s	remaining: 5.28s
# 526:	learn: 0.5591159	total: 5.87s	remaining: 5.27s
# 527:	learn: 0.5588866	total: 5.88s	remaining: 5.26s
# 528:	learn: 0.5587501	total: 5.89s	remaining: 5.25s
# 529:	learn: 0.5587210	total: 5.9s	remaining: 5.23s
# 530:	learn: 0.5585221	total: 5.91s	remaining: 5.22s
# 531:	learn: 0.5585162	total: 5.92s	remaining: 5.21s
# 532:	learn: 0.5583842	total: 5.93s	remaining: 5.2s
# 533:	learn: 0.5581251	total: 5.95s	remaining: 5.19s
# 534:	learn: 0.5578987	total: 5.96s	remaining: 5.18s
# 535:	learn: 0.5575787	total: 5.97s	remaining: 5.17s
# 536:	learn: 0.5575373	total: 5.99s	remaining: 5.16s
# 537:	learn: 0.5571479	total: 6s	remaining: 5.15s
# 538:	learn: 0.5570555	total: 6.01s	remaining: 5.14s
# 539:	learn: 0.5569345	total: 6.02s	remaining: 5.13s
# 540:	learn: 0.5567649	total: 6.03s	remaining: 5.12s
# 541:	learn: 0.5566461	total: 6.04s	remaining: 5.11s
# 542:	learn: 0.5565430	total: 6.05s	remaining: 5.09s
# 543:	learn: 0.5564087	total: 6.07s	remaining: 5.08s
# 544:	learn: 0.5563473	total: 6.08s	remaining: 5.07s
# 545:	learn: 0.5563276	total: 6.09s	remaining: 5.06s
# 546:	learn: 0.5560848	total: 6.1s	remaining: 5.05s
# 547:	learn: 0.5560083	total: 6.11s	remaining: 5.04s
# 548:	learn: 0.5558613	total: 6.12s	remaining: 5.03s
# 549:	learn: 0.5557567	total: 6.13s	remaining: 5.02s
# 550:	learn: 0.5554867	total: 6.14s	remaining: 5.01s
# 551:	learn: 0.5554785	total: 6.16s	remaining: 5s
# 552:	learn: 0.5553609	total: 6.17s	remaining: 4.98s
# 553:	learn: 0.5552920	total: 6.18s	remaining: 4.97s
# 554:	learn: 0.5552249	total: 6.19s	remaining: 4.96s
# 555:	learn: 0.5551704	total: 6.2s	remaining: 4.95s
# 556:	learn: 0.5550228	total: 6.21s	remaining: 4.94s
# 557:	learn: 0.5550037	total: 6.22s	remaining: 4.93s
# 558:	learn: 0.5549908	total: 6.24s	remaining: 4.92s
# 559:	learn: 0.5549537	total: 6.25s	remaining: 4.91s
# 560:	learn: 0.5546235	total: 6.26s	remaining: 4.9s
# 561:	learn: 0.5546109	total: 6.27s	remaining: 4.88s
# 562:	learn: 0.5544639	total: 6.28s	remaining: 4.87s
# 563:	learn: 0.5544320	total: 6.29s	remaining: 4.86s
# 564:	learn: 0.5543888	total: 6.3s	remaining: 4.85s
# 565:	learn: 0.5540499	total: 6.31s	remaining: 4.84s
# 566:	learn: 0.5538541	total: 6.32s	remaining: 4.83s
# 567:	learn: 0.5537978	total: 6.33s	remaining: 4.82s
# 568:	learn: 0.5536686	total: 6.35s	remaining: 4.81s
# 569:	learn: 0.5535502	total: 6.36s	remaining: 4.8s
# 570:	learn: 0.5534935	total: 6.37s	remaining: 4.79s
# 571:	learn: 0.5532123	total: 6.38s	remaining: 4.78s
# 572:	learn: 0.5531853	total: 6.39s	remaining: 4.76s
# 573:	learn: 0.5530290	total: 6.4s	remaining: 4.75s
# 574:	learn: 0.5529249	total: 6.42s	remaining: 4.74s
# 575:	learn: 0.5528546	total: 6.42s	remaining: 4.73s
# 576:	learn: 0.5527677	total: 6.43s	remaining: 4.72s
# 577:	learn: 0.5526229	total: 6.45s	remaining: 4.71s
# 578:	learn: 0.5525792	total: 6.46s	remaining: 4.69s
# 579:	learn: 0.5525414	total: 6.47s	remaining: 4.68s
# 580:	learn: 0.5525324	total: 6.48s	remaining: 4.67s
# 581:	learn: 0.5524594	total: 6.49s	remaining: 4.66s
# 582:	learn: 0.5524312	total: 6.5s	remaining: 4.65s
# 583:	learn: 0.5523381	total: 6.51s	remaining: 4.64s
# 584:	learn: 0.5522230	total: 6.52s	remaining: 4.63s
# 585:	learn: 0.5519806	total: 6.53s	remaining: 4.61s
# 586:	learn: 0.5517261	total: 6.54s	remaining: 4.6s
# 587:	learn: 0.5517029	total: 6.55s	remaining: 4.59s
# 588:	learn: 0.5515584	total: 6.57s	remaining: 4.58s
# 589:	learn: 0.5514158	total: 6.58s	remaining: 4.57s
# 590:	learn: 0.5513038	total: 6.59s	remaining: 4.56s
# 591:	learn: 0.5510584	total: 6.6s	remaining: 4.55s
# 592:	learn: 0.5510481	total: 6.61s	remaining: 4.54s
# 593:	learn: 0.5510334	total: 6.62s	remaining: 4.53s
# 594:	learn: 0.5509558	total: 6.63s	remaining: 4.52s
# 595:	learn: 0.5508189	total: 6.64s	remaining: 4.5s
# 596:	learn: 0.5504184	total: 6.66s	remaining: 4.49s
# 597:	learn: 0.5503230	total: 6.67s	remaining: 4.48s
# 598:	learn: 0.5501065	total: 6.68s	remaining: 4.47s
# 599:	learn: 0.5500789	total: 6.69s	remaining: 4.46s
# 600:	learn: 0.5500719	total: 6.7s	remaining: 4.45s
# 601:	learn: 0.5500345	total: 6.71s	remaining: 4.44s
# 602:	learn: 0.5500174	total: 6.72s	remaining: 4.42s
# 603:	learn: 0.5499077	total: 6.73s	remaining: 4.41s
# 604:	learn: 0.5498613	total: 6.74s	remaining: 4.4s
# 605:	learn: 0.5498511	total: 6.75s	remaining: 4.39s
# 606:	learn: 0.5497445	total: 6.76s	remaining: 4.38s
# 607:	learn: 0.5495819	total: 6.77s	remaining: 4.37s
# 608:	learn: 0.5494803	total: 6.79s	remaining: 4.36s
# 609:	learn: 0.5493269	total: 6.8s	remaining: 4.35s
# 610:	learn: 0.5491424	total: 6.81s	remaining: 4.34s
# 611:	learn: 0.5491180	total: 6.83s	remaining: 4.33s
# 612:	learn: 0.5490059	total: 6.85s	remaining: 4.32s
# 613:	learn: 0.5489257	total: 6.86s	remaining: 4.31s
# 614:	learn: 0.5489073	total: 6.87s	remaining: 4.3s
# 615:	learn: 0.5488279	total: 6.89s	remaining: 4.29s
# 616:	learn: 0.5488222	total: 6.9s	remaining: 4.28s
# 617:	learn: 0.5487183	total: 6.91s	remaining: 4.27s
# 618:	learn: 0.5486700	total: 6.92s	remaining: 4.26s
# 619:	learn: 0.5485422	total: 6.94s	remaining: 4.25s
# 620:	learn: 0.5484800	total: 6.95s	remaining: 4.24s
# 621:	learn: 0.5484269	total: 6.96s	remaining: 4.23s
# 622:	learn: 0.5483450	total: 6.97s	remaining: 4.22s
# 623:	learn: 0.5483073	total: 6.98s	remaining: 4.21s
# 624:	learn: 0.5480397	total: 7s	remaining: 4.2s
# 625:	learn: 0.5480114	total: 7.01s	remaining: 4.19s
# 626:	learn: 0.5479822	total: 7.02s	remaining: 4.17s
# 627:	learn: 0.5479440	total: 7.03s	remaining: 4.16s
# 628:	learn: 0.5478027	total: 7.04s	remaining: 4.15s
# 629:	learn: 0.5476443	total: 7.05s	remaining: 4.14s
# 630:	learn: 0.5473488	total: 7.06s	remaining: 4.13s
# 631:	learn: 0.5472426	total: 7.07s	remaining: 4.12s
# 632:	learn: 0.5472105	total: 7.08s	remaining: 4.11s
# 633:	learn: 0.5470540	total: 7.1s	remaining: 4.1s
# 634:	learn: 0.5470350	total: 7.11s	remaining: 4.08s
# 635:	learn: 0.5469421	total: 7.12s	remaining: 4.07s
# 636:	learn: 0.5468617	total: 7.13s	remaining: 4.06s
# 637:	learn: 0.5468264	total: 7.14s	remaining: 4.05s
# 638:	learn: 0.5464407	total: 7.15s	remaining: 4.04s
# 639:	learn: 0.5463661	total: 7.16s	remaining: 4.03s
# 640:	learn: 0.5463254	total: 7.17s	remaining: 4.01s
# 641:	learn: 0.5463071	total: 7.18s	remaining: 4s
# 642:	learn: 0.5462404	total: 7.2s	remaining: 4s
# 643:	learn: 0.5461664	total: 7.21s	remaining: 3.98s
# 644:	learn: 0.5460289	total: 7.22s	remaining: 3.97s
# 645:	learn: 0.5459184	total: 7.23s	remaining: 3.96s
# 646:	learn: 0.5458293	total: 7.24s	remaining: 3.95s
# 647:	learn: 0.5457179	total: 7.25s	remaining: 3.94s
# 648:	learn: 0.5455953	total: 7.26s	remaining: 3.93s
# 649:	learn: 0.5454353	total: 7.28s	remaining: 3.92s
# 650:	learn: 0.5454093	total: 7.29s	remaining: 3.91s
# 651:	learn: 0.5452416	total: 7.3s	remaining: 3.9s
# 652:	learn: 0.5450910	total: 7.31s	remaining: 3.88s
# 653:	learn: 0.5450710	total: 7.32s	remaining: 3.87s
# 654:	learn: 0.5448503	total: 7.33s	remaining: 3.86s
# 655:	learn: 0.5446872	total: 7.34s	remaining: 3.85s
# 656:	learn: 0.5445535	total: 7.35s	remaining: 3.84s
# 657:	learn: 0.5444091	total: 7.37s	remaining: 3.83s
# 658:	learn: 0.5442649	total: 7.38s	remaining: 3.82s
# 659:	learn: 0.5440588	total: 7.39s	remaining: 3.81s
# 660:	learn: 0.5440176	total: 7.4s	remaining: 3.79s
# 661:	learn: 0.5436828	total: 7.41s	remaining: 3.78s
# 662:	learn: 0.5435770	total: 7.42s	remaining: 3.77s
# 663:	learn: 0.5435484	total: 7.43s	remaining: 3.76s
# 664:	learn: 0.5433664	total: 7.45s	remaining: 3.75s
# 665:	learn: 0.5432814	total: 7.46s	remaining: 3.74s
# 666:	learn: 0.5432246	total: 7.47s	remaining: 3.73s
# 667:	learn: 0.5431280	total: 7.48s	remaining: 3.72s
# 668:	learn: 0.5429841	total: 7.49s	remaining: 3.71s
# 669:	learn: 0.5428044	total: 7.5s	remaining: 3.69s
# 670:	learn: 0.5427486	total: 7.51s	remaining: 3.68s
# 671:	learn: 0.5426147	total: 7.52s	remaining: 3.67s
# 672:	learn: 0.5424559	total: 7.54s	remaining: 3.66s
# 673:	learn: 0.5424371	total: 7.55s	remaining: 3.65s
# 674:	learn: 0.5423754	total: 7.56s	remaining: 3.64s
# 675:	learn: 0.5423530	total: 7.57s	remaining: 3.63s
# 676:	learn: 0.5422711	total: 7.58s	remaining: 3.62s
# 677:	learn: 0.5419910	total: 7.6s	remaining: 3.61s
# 678:	learn: 0.5418969	total: 7.61s	remaining: 3.6s
# 679:	learn: 0.5418616	total: 7.62s	remaining: 3.59s
# 680:	learn: 0.5416811	total: 7.63s	remaining: 3.57s
# 681:	learn: 0.5414905	total: 7.64s	remaining: 3.56s
# 682:	learn: 0.5414009	total: 7.66s	remaining: 3.55s
# 683:	learn: 0.5413346	total: 7.67s	remaining: 3.54s
# 684:	learn: 0.5412333	total: 7.68s	remaining: 3.53s
# 685:	learn: 0.5410981	total: 7.69s	remaining: 3.52s
# 686:	learn: 0.5410227	total: 7.7s	remaining: 3.51s
# 687:	learn: 0.5407677	total: 7.71s	remaining: 3.5s
# 688:	learn: 0.5406554	total: 7.72s	remaining: 3.48s
# 689:	learn: 0.5405362	total: 7.73s	remaining: 3.47s
# 690:	learn: 0.5404495	total: 7.74s	remaining: 3.46s
# 691:	learn: 0.5403238	total: 7.75s	remaining: 3.45s
# 692:	learn: 0.5402019	total: 7.76s	remaining: 3.44s
# 693:	learn: 0.5400074	total: 7.78s	remaining: 3.43s
# 694:	learn: 0.5399441	total: 7.79s	remaining: 3.42s
# 695:	learn: 0.5399255	total: 7.8s	remaining: 3.41s
# 696:	learn: 0.5396201	total: 7.82s	remaining: 3.4s
# 697:	learn: 0.5394827	total: 7.83s	remaining: 3.39s
# 698:	learn: 0.5393709	total: 7.84s	remaining: 3.38s
# 699:	learn: 0.5392939	total: 7.85s	remaining: 3.36s
# 700:	learn: 0.5391600	total: 7.86s	remaining: 3.35s
# 701:	learn: 0.5390117	total: 7.87s	remaining: 3.34s
# 702:	learn: 0.5386124	total: 7.89s	remaining: 3.33s
# 703:	learn: 0.5384710	total: 7.9s	remaining: 3.32s
# 704:	learn: 0.5383070	total: 7.91s	remaining: 3.31s
# 705:	learn: 0.5381427	total: 7.92s	remaining: 3.3s
# 706:	learn: 0.5379696	total: 7.93s	remaining: 3.29s
# 707:	learn: 0.5379634	total: 7.95s	remaining: 3.28s
# 708:	learn: 0.5378119	total: 7.96s	remaining: 3.27s
# 709:	learn: 0.5377988	total: 7.97s	remaining: 3.25s
# 710:	learn: 0.5377197	total: 7.98s	remaining: 3.24s
# 711:	learn: 0.5376053	total: 7.99s	remaining: 3.23s
# 712:	learn: 0.5375322	total: 8.01s	remaining: 3.22s
# 713:	learn: 0.5375118	total: 8.02s	remaining: 3.21s
# 714:	learn: 0.5373951	total: 8.03s	remaining: 3.2s
# 715:	learn: 0.5373049	total: 8.04s	remaining: 3.19s
# 716:	learn: 0.5371504	total: 8.05s	remaining: 3.18s
# 717:	learn: 0.5370835	total: 8.06s	remaining: 3.17s
# 718:	learn: 0.5369219	total: 8.07s	remaining: 3.15s
# 719:	learn: 0.5365799	total: 8.08s	remaining: 3.14s
# 720:	learn: 0.5365711	total: 8.09s	remaining: 3.13s
# 721:	learn: 0.5364938	total: 8.1s	remaining: 3.12s
# 722:	learn: 0.5364747	total: 8.11s	remaining: 3.11s
# 723:	learn: 0.5364357	total: 8.12s	remaining: 3.1s
# 724:	learn: 0.5363299	total: 8.13s	remaining: 3.08s
# 725:	learn: 0.5362487	total: 8.14s	remaining: 3.07s
# 726:	learn: 0.5360365	total: 8.15s	remaining: 3.06s
# 727:	learn: 0.5360113	total: 8.16s	remaining: 3.05s
# 728:	learn: 0.5359926	total: 8.18s	remaining: 3.04s
# 729:	learn: 0.5358810	total: 8.19s	remaining: 3.03s
# 730:	learn: 0.5357066	total: 8.2s	remaining: 3.02s
# 731:	learn: 0.5356790	total: 8.21s	remaining: 3s
# 732:	learn: 0.5356279	total: 8.22s	remaining: 2.99s
# 733:	learn: 0.5354009	total: 8.23s	remaining: 2.98s
# 734:	learn: 0.5353795	total: 8.24s	remaining: 2.97s
# 735:	learn: 0.5351953	total: 8.25s	remaining: 2.96s
# 736:	learn: 0.5351136	total: 8.26s	remaining: 2.95s
# 737:	learn: 0.5350742	total: 8.27s	remaining: 2.94s
# 738:	learn: 0.5350267	total: 8.28s	remaining: 2.93s
# 739:	learn: 0.5349160	total: 8.3s	remaining: 2.92s
# 740:	learn: 0.5348174	total: 8.31s	remaining: 2.9s
# 741:	learn: 0.5347919	total: 8.32s	remaining: 2.89s
# 742:	learn: 0.5346075	total: 8.33s	remaining: 2.88s
# 743:	learn: 0.5343380	total: 8.34s	remaining: 2.87s
# 744:	learn: 0.5341533	total: 8.35s	remaining: 2.86s
# 745:	learn: 0.5340832	total: 8.36s	remaining: 2.85s
# 746:	learn: 0.5337881	total: 8.38s	remaining: 2.84s
# 747:	learn: 0.5336570	total: 8.39s	remaining: 2.83s
# 748:	learn: 0.5335810	total: 8.4s	remaining: 2.81s
# 749:	learn: 0.5335097	total: 8.41s	remaining: 2.8s
# 750:	learn: 0.5333698	total: 8.42s	remaining: 2.79s
# 751:	learn: 0.5331569	total: 8.43s	remaining: 2.78s
# 752:	learn: 0.5331152	total: 8.44s	remaining: 2.77s
# 753:	learn: 0.5330515	total: 8.45s	remaining: 2.76s
# 754:	learn: 0.5328779	total: 8.46s	remaining: 2.75s
# 755:	learn: 0.5327439	total: 8.47s	remaining: 2.73s
# 756:	learn: 0.5325684	total: 8.49s	remaining: 2.72s
# 757:	learn: 0.5323841	total: 8.5s	remaining: 2.71s
# 758:	learn: 0.5322554	total: 8.51s	remaining: 2.7s
# 759:	learn: 0.5321752	total: 8.52s	remaining: 2.69s
# 760:	learn: 0.5319305	total: 8.53s	remaining: 2.68s
# 761:	learn: 0.5318443	total: 8.54s	remaining: 2.67s
# 762:	learn: 0.5318276	total: 8.55s	remaining: 2.66s
# 763:	learn: 0.5317245	total: 8.56s	remaining: 2.65s
# 764:	learn: 0.5316410	total: 8.57s	remaining: 2.63s
# 765:	learn: 0.5315728	total: 8.59s	remaining: 2.62s
# 766:	learn: 0.5315631	total: 8.6s	remaining: 2.61s
# 767:	learn: 0.5312088	total: 8.61s	remaining: 2.6s
# 768:	learn: 0.5311833	total: 8.62s	remaining: 2.59s
# 769:	learn: 0.5311790	total: 8.63s	remaining: 2.58s
# 770:	learn: 0.5311193	total: 8.64s	remaining: 2.57s
# 771:	learn: 0.5309627	total: 8.65s	remaining: 2.56s
# 772:	learn: 0.5308268	total: 8.66s	remaining: 2.54s
# 773:	learn: 0.5308111	total: 8.68s	remaining: 2.53s
# 774:	learn: 0.5307569	total: 8.69s	remaining: 2.52s
# 775:	learn: 0.5307485	total: 8.7s	remaining: 2.51s
# 776:	learn: 0.5306562	total: 8.71s	remaining: 2.5s
# 777:	learn: 0.5304246	total: 8.72s	remaining: 2.49s
# 778:	learn: 0.5302754	total: 8.73s	remaining: 2.48s
# 779:	learn: 0.5302133	total: 8.74s	remaining: 2.46s
# 780:	learn: 0.5301998	total: 8.75s	remaining: 2.45s
# 781:	learn: 0.5301926	total: 8.76s	remaining: 2.44s
# 782:	learn: 0.5301814	total: 8.77s	remaining: 2.43s
# 783:	learn: 0.5301606	total: 8.78s	remaining: 2.42s
# 784:	learn: 0.5300165	total: 8.79s	remaining: 2.41s
# 785:	learn: 0.5299730	total: 8.81s	remaining: 2.4s
# 786:	learn: 0.5298016	total: 8.82s	remaining: 2.39s
# 787:	learn: 0.5297314	total: 8.83s	remaining: 2.38s
# 788:	learn: 0.5296750	total: 8.84s	remaining: 2.36s
# 789:	learn: 0.5294936	total: 8.85s	remaining: 2.35s
# 790:	learn: 0.5292220	total: 8.87s	remaining: 2.34s
# 791:	learn: 0.5290693	total: 8.88s	remaining: 2.33s
# 792:	learn: 0.5289406	total: 8.89s	remaining: 2.32s
# 793:	learn: 0.5288284	total: 8.9s	remaining: 2.31s
# 794:	learn: 0.5287002	total: 8.91s	remaining: 2.3s
# 795:	learn: 0.5285810	total: 8.92s	remaining: 2.29s
# 796:	learn: 0.5285554	total: 8.93s	remaining: 2.27s
# 797:	learn: 0.5282841	total: 8.94s	remaining: 2.26s
# 798:	learn: 0.5280772	total: 8.95s	remaining: 2.25s
# 799:	learn: 0.5280724	total: 8.96s	remaining: 2.24s
# 800:	learn: 0.5279963	total: 8.97s	remaining: 2.23s
# 801:	learn: 0.5279592	total: 8.98s	remaining: 2.22s
# 802:	learn: 0.5278578	total: 8.99s	remaining: 2.21s
# 803:	learn: 0.5278531	total: 9.01s	remaining: 2.19s
# 804:	learn: 0.5275918	total: 9.02s	remaining: 2.18s
# 805:	learn: 0.5275057	total: 9.03s	remaining: 2.17s
# 806:	learn: 0.5273727	total: 9.04s	remaining: 2.16s
# 807:	learn: 0.5273178	total: 9.05s	remaining: 2.15s
# 808:	learn: 0.5271742	total: 9.06s	remaining: 2.14s
# 809:	learn: 0.5271370	total: 9.07s	remaining: 2.13s
# 810:	learn: 0.5271075	total: 9.09s	remaining: 2.12s
# 811:	learn: 0.5270454	total: 9.1s	remaining: 2.11s
# 812:	learn: 0.5268508	total: 9.11s	remaining: 2.1s
# 813:	learn: 0.5266674	total: 9.12s	remaining: 2.08s
# 814:	learn: 0.5266433	total: 9.13s	remaining: 2.07s
# 815:	learn: 0.5265031	total: 9.14s	remaining: 2.06s
# 816:	learn: 0.5263411	total: 9.15s	remaining: 2.05s
# 817:	learn: 0.5262687	total: 9.16s	remaining: 2.04s
# 818:	learn: 0.5260953	total: 9.17s	remaining: 2.03s
# 819:	learn: 0.5259482	total: 9.19s	remaining: 2.02s
# 820:	learn: 0.5257876	total: 9.2s	remaining: 2s
# 821:	learn: 0.5255889	total: 9.21s	remaining: 1.99s
# 822:	learn: 0.5255428	total: 9.22s	remaining: 1.98s
# 823:	learn: 0.5253904	total: 9.23s	remaining: 1.97s
# 824:	learn: 0.5253754	total: 9.24s	remaining: 1.96s
# 825:	learn: 0.5252850	total: 9.25s	remaining: 1.95s
# 826:	learn: 0.5252529	total: 9.27s	remaining: 1.94s
# 827:	learn: 0.5252455	total: 9.28s	remaining: 1.93s
# 828:	learn: 0.5252380	total: 9.29s	remaining: 1.92s
# 829:	learn: 0.5251670	total: 9.3s	remaining: 1.9s
# 830:	learn: 0.5251547	total: 9.31s	remaining: 1.89s
# 831:	learn: 0.5250834	total: 9.32s	remaining: 1.88s
# 832:	learn: 0.5250285	total: 9.33s	remaining: 1.87s
# 833:	learn: 0.5248101	total: 9.34s	remaining: 1.86s
# 834:	learn: 0.5246367	total: 9.35s	remaining: 1.85s
# 835:	learn: 0.5245802	total: 9.36s	remaining: 1.84s
# 836:	learn: 0.5244492	total: 9.37s	remaining: 1.82s
# 837:	learn: 0.5242886	total: 9.38s	remaining: 1.81s
# 838:	learn: 0.5242376	total: 9.39s	remaining: 1.8s
# 839:	learn: 0.5241988	total: 9.41s	remaining: 1.79s
# 840:	learn: 0.5239399	total: 9.42s	remaining: 1.78s
# 841:	learn: 0.5236538	total: 9.43s	remaining: 1.77s
# 842:	learn: 0.5236380	total: 9.44s	remaining: 1.76s
# 843:	learn: 0.5233999	total: 9.45s	remaining: 1.75s
# 844:	learn: 0.5233495	total: 9.46s	remaining: 1.74s
# 845:	learn: 0.5233316	total: 9.47s	remaining: 1.72s
# 846:	learn: 0.5232322	total: 9.48s	remaining: 1.71s
# 847:	learn: 0.5231192	total: 9.49s	remaining: 1.7s
# 848:	learn: 0.5228620	total: 9.51s	remaining: 1.69s
# 849:	learn: 0.5228311	total: 9.52s	remaining: 1.68s
# 850:	learn: 0.5227610	total: 9.53s	remaining: 1.67s
# 851:	learn: 0.5226924	total: 9.54s	remaining: 1.66s
# 852:	learn: 0.5225793	total: 9.55s	remaining: 1.65s
# 853:	learn: 0.5224863	total: 9.56s	remaining: 1.63s
# 854:	learn: 0.5222521	total: 9.57s	remaining: 1.62s
# 855:	learn: 0.5221556	total: 9.58s	remaining: 1.61s
# 856:	learn: 0.5220888	total: 9.6s	remaining: 1.6s
# 857:	learn: 0.5220802	total: 9.61s	remaining: 1.59s
# 858:	learn: 0.5220566	total: 9.62s	remaining: 1.58s
# 859:	learn: 0.5216915	total: 9.63s	remaining: 1.57s
# 860:	learn: 0.5215146	total: 9.64s	remaining: 1.56s
# 861:	learn: 0.5213483	total: 9.65s	remaining: 1.54s
# 862:	learn: 0.5211810	total: 9.67s	remaining: 1.53s
# 863:	learn: 0.5211017	total: 9.68s	remaining: 1.52s
# 864:	learn: 0.5210456	total: 9.69s	remaining: 1.51s
# 865:	learn: 0.5207889	total: 9.7s	remaining: 1.5s
# 866:	learn: 0.5207257	total: 9.71s	remaining: 1.49s
# 867:	learn: 0.5207156	total: 9.72s	remaining: 1.48s
# 868:	learn: 0.5207072	total: 9.73s	remaining: 1.47s
# 869:	learn: 0.5206344	total: 9.74s	remaining: 1.46s
# 870:	learn: 0.5205182	total: 9.75s	remaining: 1.44s
# 871:	learn: 0.5205058	total: 9.76s	remaining: 1.43s
# 872:	learn: 0.5203301	total: 9.78s	remaining: 1.42s
# 873:	learn: 0.5202119	total: 9.79s	remaining: 1.41s
# 874:	learn: 0.5201603	total: 9.8s	remaining: 1.4s
# 875:	learn: 0.5199923	total: 9.81s	remaining: 1.39s
# 876:	learn: 0.5199401	total: 9.82s	remaining: 1.38s
# 877:	learn: 0.5197818	total: 9.83s	remaining: 1.37s
# 878:	learn: 0.5197256	total: 9.85s	remaining: 1.35s
# 879:	learn: 0.5196830	total: 9.86s	remaining: 1.34s
# 880:	learn: 0.5196317	total: 9.88s	remaining: 1.33s
# 881:	learn: 0.5194704	total: 9.9s	remaining: 1.32s
# 882:	learn: 0.5194298	total: 9.91s	remaining: 1.31s
# 883:	learn: 0.5194235	total: 9.93s	remaining: 1.3s
# 884:	learn: 0.5193656	total: 9.94s	remaining: 1.29s
# 885:	learn: 0.5193529	total: 9.95s	remaining: 1.28s
# 886:	learn: 0.5190827	total: 9.96s	remaining: 1.27s
# 887:	learn: 0.5190318	total: 9.98s	remaining: 1.26s
# 888:	learn: 0.5189464	total: 9.99s	remaining: 1.25s
# 889:	learn: 0.5188133	total: 10s	remaining: 1.24s
# 890:	learn: 0.5185268	total: 10s	remaining: 1.23s
# 891:	learn: 0.5184470	total: 10s	remaining: 1.21s
# 892:	learn: 0.5182450	total: 10s	remaining: 1.2s
# 893:	learn: 0.5182170	total: 10.1s	remaining: 1.19s
# 894:	learn: 0.5182021	total: 10.1s	remaining: 1.18s
# 895:	learn: 0.5180260	total: 10.1s	remaining: 1.17s
# 896:	learn: 0.5179506	total: 10.1s	remaining: 1.16s
# 897:	learn: 0.5178266	total: 10.1s	remaining: 1.15s
# 898:	learn: 0.5176658	total: 10.1s	remaining: 1.14s
# 899:	learn: 0.5174029	total: 10.1s	remaining: 1.13s
# 900:	learn: 0.5172731	total: 10.1s	remaining: 1.11s
# 901:	learn: 0.5171898	total: 10.1s	remaining: 1.1s
# 902:	learn: 0.5171345	total: 10.2s	remaining: 1.09s
# 903:	learn: 0.5171292	total: 10.2s	remaining: 1.08s
# 904:	learn: 0.5170928	total: 10.2s	remaining: 1.07s
# 905:	learn: 0.5170650	total: 10.2s	remaining: 1.06s
# 906:	learn: 0.5169211	total: 10.2s	remaining: 1.05s
# 907:	learn: 0.5168840	total: 10.2s	remaining: 1.03s
# 908:	learn: 0.5167876	total: 10.2s	remaining: 1.02s
# 909:	learn: 0.5167772	total: 10.2s	remaining: 1.01s
# 910:	learn: 0.5166693	total: 10.3s	remaining: 1s
# 911:	learn: 0.5166176	total: 10.3s	remaining: 990ms
# 912:	learn: 0.5165993	total: 10.3s	remaining: 979ms
# 913:	learn: 0.5164439	total: 10.3s	remaining: 968ms
# 914:	learn: 0.5163957	total: 10.3s	remaining: 957ms
# 915:	learn: 0.5162654	total: 10.3s	remaining: 945ms
# 916:	learn: 0.5162275	total: 10.3s	remaining: 934ms
# 917:	learn: 0.5161809	total: 10.3s	remaining: 923ms
# 918:	learn: 0.5161651	total: 10.3s	remaining: 911ms
# 919:	learn: 0.5161540	total: 10.4s	remaining: 900ms
# 920:	learn: 0.5160151	total: 10.4s	remaining: 889ms
# 921:	learn: 0.5159526	total: 10.4s	remaining: 878ms
# 922:	learn: 0.5159139	total: 10.4s	remaining: 866ms
# 923:	learn: 0.5158350	total: 10.4s	remaining: 855ms
# 924:	learn: 0.5157762	total: 10.4s	remaining: 844ms
# 925:	learn: 0.5156633	total: 10.4s	remaining: 833ms
# 926:	learn: 0.5154649	total: 10.4s	remaining: 821ms
# 927:	learn: 0.5150879	total: 10.4s	remaining: 810ms
# 928:	learn: 0.5150441	total: 10.5s	remaining: 799ms
# 929:	learn: 0.5147652	total: 10.5s	remaining: 788ms
# 930:	learn: 0.5146114	total: 10.5s	remaining: 777ms
# 931:	learn: 0.5144171	total: 10.5s	remaining: 765ms
# 932:	learn: 0.5141375	total: 10.5s	remaining: 754ms
# 933:	learn: 0.5141118	total: 10.5s	remaining: 743ms
# 934:	learn: 0.5140559	total: 10.5s	remaining: 732ms
# 935:	learn: 0.5139702	total: 10.5s	remaining: 720ms
# 936:	learn: 0.5138439	total: 10.5s	remaining: 709ms
# 937:	learn: 0.5136821	total: 10.6s	remaining: 698ms
# 938:	learn: 0.5135131	total: 10.6s	remaining: 687ms
# 939:	learn: 0.5134114	total: 10.6s	remaining: 675ms
# 940:	learn: 0.5133780	total: 10.6s	remaining: 664ms
# 941:	learn: 0.5132428	total: 10.6s	remaining: 653ms
# 942:	learn: 0.5130016	total: 10.6s	remaining: 642ms
# 943:	learn: 0.5128389	total: 10.6s	remaining: 630ms
# 944:	learn: 0.5125296	total: 10.6s	remaining: 619ms
# 945:	learn: 0.5125148	total: 10.6s	remaining: 608ms
# 946:	learn: 0.5122036	total: 10.7s	remaining: 597ms
# 947:	learn: 0.5119262	total: 10.7s	remaining: 585ms
# 948:	learn: 0.5117506	total: 10.7s	remaining: 574ms
# 949:	learn: 0.5116469	total: 10.7s	remaining: 563ms
# 950:	learn: 0.5115513	total: 10.7s	remaining: 552ms
# 951:	learn: 0.5113091	total: 10.7s	remaining: 540ms
# 952:	learn: 0.5112378	total: 10.7s	remaining: 529ms
# 953:	learn: 0.5110288	total: 10.7s	remaining: 518ms
# 954:	learn: 0.5108734	total: 10.8s	remaining: 507ms
# 955:	learn: 0.5107672	total: 10.8s	remaining: 495ms
# 956:	learn: 0.5107187	total: 10.8s	remaining: 484ms
# 957:	learn: 0.5105789	total: 10.8s	remaining: 473ms
# 958:	learn: 0.5105117	total: 10.8s	remaining: 462ms
# 959:	learn: 0.5104335	total: 10.8s	remaining: 450ms
# 960:	learn: 0.5101504	total: 10.8s	remaining: 439ms
# 961:	learn: 0.5100570	total: 10.8s	remaining: 428ms
# 962:	learn: 0.5099499	total: 10.8s	remaining: 417ms
# 963:	learn: 0.5099265	total: 10.9s	remaining: 405ms
# 964:	learn: 0.5096965	total: 10.9s	remaining: 394ms
# 965:	learn: 0.5096514	total: 10.9s	remaining: 383ms
# 966:	learn: 0.5096019	total: 10.9s	remaining: 372ms
# 967:	learn: 0.5093008	total: 10.9s	remaining: 361ms
# 968:	learn: 0.5092212	total: 10.9s	remaining: 349ms
# 969:	learn: 0.5091716	total: 10.9s	remaining: 338ms
# 970:	learn: 0.5090899	total: 10.9s	remaining: 327ms
# 971:	learn: 0.5090825	total: 10.9s	remaining: 315ms
# 972:	learn: 0.5089887	total: 11s	remaining: 304ms
# 973:	learn: 0.5088677	total: 11s	remaining: 293ms
# 974:	learn: 0.5088251	total: 11s	remaining: 282ms
# 975:	learn: 0.5087505	total: 11s	remaining: 270ms
# 976:	learn: 0.5086616	total: 11s	remaining: 259ms
# 977:	learn: 0.5084534	total: 11s	remaining: 248ms
# 978:	learn: 0.5083610	total: 11s	remaining: 237ms
# 979:	learn: 0.5083245	total: 11s	remaining: 225ms
# 980:	learn: 0.5082721	total: 11s	remaining: 214ms
# 981:	learn: 0.5082088	total: 11.1s	remaining: 203ms
# 982:	learn: 0.5080394	total: 11.1s	remaining: 192ms
# 983:	learn: 0.5078972	total: 11.1s	remaining: 180ms
# 984:	learn: 0.5076140	total: 11.1s	remaining: 169ms
# 985:	learn: 0.5075150	total: 11.1s	remaining: 158ms
# 986:	learn: 0.5074463	total: 11.1s	remaining: 146ms
# 987:	learn: 0.5072915	total: 11.1s	remaining: 135ms
# 988:	learn: 0.5071737	total: 11.1s	remaining: 124ms
# 989:	learn: 0.5070758	total: 11.2s	remaining: 113ms
# 990:	learn: 0.5067756	total: 11.2s	remaining: 101ms
# 991:	learn: 0.5065922	total: 11.2s	remaining: 90.2ms
# 992:	learn: 0.5064669	total: 11.2s	remaining: 78.9ms
# 993:	learn: 0.5063727	total: 11.2s	remaining: 67.6ms
# 994:	learn: 0.5061874	total: 11.2s	remaining: 56.4ms
# 995:	learn: 0.5061630	total: 11.2s	remaining: 45.1ms
# 996:	learn: 0.5061017	total: 11.2s	remaining: 33.8ms
# 997:	learn: 0.5060893	total: 11.2s	remaining: 22.5ms
# 998:	learn: 0.5059855	total: 11.3s	remaining: 11.3ms
# 999:	learn: 0.5059313	total: 11.3s	remaining: 0us
# Test Balanced Accuracy: 0.36496781058958744

# %% [markdown]
# **11. (2 балла) Пришлите в Контест balanced_accuracy_score на тестовой выборке, округлённый до двух знаков после запятой**. Стало ли сильно лучше от того, что мы воспользовались таким крутым классификатором?
